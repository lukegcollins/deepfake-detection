# %% [markdown]
# # Base Model Experiments
#
# **Import Packages**
# The following cell will import the required packages, and print the their current version, and indicate how many GPU's are connected to the system.

# %%
# Project Dependencies | Double Click to Expand/Collapse
# Author: Luke Collins 
# Date Created: 2023-09-28
# Date Modified: 2023-09-28
# Description: This file contains the code used in the publication "XX" to select the base_model for this study.

import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import pydot


import matplotlib as mpl
import matplotlib.pyplot as plt

import sklearn as sk
from sklearn.metrics import confusion_matrix, roc_curve, f1_score, auc
from sklearn.metrics import precision_score, recall_score

import tensorflow as tf
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.layers import Input, Dense, Flatten, GlobalAveragePooling2D, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.applications import Xception, InceptionV3, ResNet50, VGG16, VGG19 
from tensorflow.keras.applications.xception import preprocess_input as xception_preprocess_input
from tensorflow.keras.applications.inception_v3 import preprocess_input as inception_v3_preprocess_input
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet50_preprocess_input
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg16_preprocess_input
from tensorflow.keras.applications.vgg19 import preprocess_input as vgg19_preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall, AUC
from tensorflow.keras.regularizers import l1, l2, l1_l2
from tensorflow.keras.utils import plot_model

print("Printing versions of libraries used:")
print("Numpy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Seaborn:", sns.__version__)
print("Pydot:", pydot.__version__)
print("Matplotlib:", mpl.__version__)
print("Scikit-learn version:", sk.__version__)
print("Tensorflow version:", tf.__version__)
print("Number of GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2023-06-02 16:50:10.864831: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-02 16:50:11.473515: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Printing versions of libraries used:
# Numpy version: 1.23.5
# Pandas version: 2.0.1
# Seaborn: 0.12.2
# Pydot: 1.4.2
# Matplotlib: 3.7.1
# Scikit-learn version: 1.2.2
# Tensorflow version: 2.12.0
# Number of GPUs Available:  1
# 2023-06-02 16:50:12.052109: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:12.114460: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:12.114872: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ----
# ## **Notebook Configuration Cell**
# The following cell should always be run directly after the packages are imported, this is where you will configure directories to suit your system if reproducing this experiment at home. Do not proceed if your cells output produces and `false` for any of the directories.
#
# **Warning**
# Before altering path, if you wish the use a different dataset on a specific test, we recommend change the `experiment_train_directory` or `experiment_test_directory` on lines 5-6 of the experiment cell.

# %%
# Project Configuration File | Double Click to Expand/Collapse
# Load Directories
train_directory = "../datasets/train-20"
test_directory = "../datasets/test-20"
experiment_base_directory = "../experiments/base-model-selection"

# Create directories if they don't exist
os.makedirs(experiment_base_directory, exist_ok=True)

# Check if directories exist
print("Train directory exists:", os.path.isdir(train_directory))
print("Test directory exists:", os.path.isdir(test_directory))
print("Experiment directory exists:", os.path.isdir(experiment_base_directory))
# Out:
# Train directory exists: True
# Test directory exists: True
# Experiment directory exists: True

# %% [markdown]
# ----
# ## **Dataset Creation Utilities**
# The following cell will define the functions required to create the training, validation and test datasets.

# %%
# Project Dataset Creation Utilities | Double Click to Expand/Collapse
def create_train_val_datasets(
    preprocessing_model,
    input_dir,
    img_height=299,
    img_width=299,
    batch_size=32,
    augment_data=False
):
    """
    Creates train and validation datasets from images in the input directory.

    Args:
        preprocessing_model (function): The preprocessing function to apply to the images.
        input_dir (str): The path to the input directory containing 'real' and 'fake' subdirectories.
        img_height (int): The height of the input images. Default is 299.
        img_width (int): The width of the input images. Default is 299.
        batch_size (int): The batch size for the data generators. Default is 32.
    Returns:
        tf.data.Dataset, tf.data.Dataset: The train and validation datasets.
    """
    normalDatagen = ImageDataGenerator(
        preprocessing_function=preprocessing_model,
        validation_split=0.2                # Create a 80/20 train/validation split
    )

    augmentDatagen = ImageDataGenerator(
            preprocessing_function=preprocessing_model,
            rotation_range=10,              # Random rotation within +/- 10 degrees
            width_shift_range=0.1,          # Random horizontal shift within +/- 10% of image width
            height_shift_range=0.1,         # Random vertical shift within +/- 10% of image height
            shear_range=0.1,                # Random shearing
            zoom_range=0.1,                 # Random zooming
            horizontal_flip=True,           # Horizontal flipping
            brightness_range=[0.8, 1.2],    # Random brightness adjustment within the given range
            validation_split=0.2            # Create a 80/20 train/validation split
    )


    datagen = augmentDatagen if augment_data else normalDatagen
    train_gen = datagen.flow_from_directory(
        input_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode="binary",
        subset="training",
        shuffle=True
    )

    val_gen = normalDatagen.flow_from_directory(
        input_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode="binary",
        subset="validation",
        shuffle=True
    )
    
    return train_gen, val_gen

def create_test_dataset(
    preprocessing_model,
    input_dir,
    img_height=299,
    img_width=299,
    batch_size=32,
):
    """
    Creates a test dataset from images in the input directory.

    Args:
        preprocessing_model (function): The preprocessing function to apply to the images.
        input_dir (str): The path to the input directory containing 'real' and 'fake' subdirectories..
        img_height (int): The height of the input images. Default is 299.
        img_width (int): The width of the input images. Default is 299.
        batch_size (int): The batch size for the data generators. Default is 32.
        save_dataset (bool): Whether to save the dataset as a TFRecord file. Default is True.
    Returns:
        tf.data.Dataset: The test dataset.
    """
    datagen = ImageDataGenerator(
        preprocessing_function=preprocessing_model
    )

    return datagen.flow_from_directory(
        input_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode="binary",
        shuffle=True,
    )

# %% [markdown]
# ----
# ## **Plotting Utilities**
# The following cell will define the functions required to plot model accuracy on training and validation metrics.

# %%
# Project Plot/Graphic Creation Utilities | Double Click to Expand/Collapse
def create_accuracy_plots(folder_path):
    """
    Creates accuracy plots for each epoch report in the specified folder.

    Args:
        folder_path (str): Path to the folder containing the epoch reports.

    Returns:
        None
    """
    # Get a list of all CSV files in the folder
    epoch_reports = [file for file in os.listdir(folder_path) if file.endswith('epochs_report.csv')]

    # Create the accuracy_plots directory if it doesn't exist
    accuracy_plots_path = os.path.join(folder_path, 'accuracy_plots')
    os.makedirs(accuracy_plots_path, exist_ok=True)

    # Cycle through the epoch reports and create plots
    for report in epoch_reports:
        # Read the epoch history CSV file
        report_path = os.path.join(folder_path, report)
        df = pd.read_csv(report_path)

        # Get the number of epochs
        epochs = range(1, len(df) + 1)

        # Extract the relevant columns
        train_accuracy = df['binary_accuracy']
        val_accuracy = df['val_binary_accuracy']

        # Create the plot
        plt.figure(figsize=(8, 6))
        plt.plot(epochs, train_accuracy, label='Train Accuracy')
        plt.plot(epochs, val_accuracy, label='Validation Accuracy')

        # Set plot title and labels
        plot_name = report.split('_')[0] + '_accuracy_plot.png'
        plt.title(f'Accuracy History - {plot_name}')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')

        # Set plot legend
        plt.legend()

        # Save the plot
        plot_path = os.path.join(accuracy_plots_path, plot_name)
        plt.savefig(plot_path)

        # Display the plot (optional)
        plt.show()

def create_all_metrics_plots(folder_path):
    """
    Creates plots for various metrics (accuracy, precision, recall) for each epoch report in the specified folder.

    Args:
        folder_path (str): Path to the folder containing the epoch reports.

    Returns:
        None
    """
    # Get a list of all CSV files in the folder
    epoch_reports = [file for file in os.listdir(folder_path) if file.endswith('epochs_report.csv')]

    # Create the accuracy_plots directory if it doesn't exist
    accuracy_plots_path = os.path.join(folder_path, 'accuracy_plots')
    os.makedirs(accuracy_plots_path, exist_ok=True)

    # Cycle through the epoch reports and create plots
    for report in epoch_reports:
        # Read the epoch history CSV file
        report_path = os.path.join(folder_path, report)
        df = pd.read_csv(report_path)

        # Get the number of epochs
        epochs = range(1, len(df) + 1)

        # Extract the relevant columns
        train_accuracy = df['binary_accuracy']
        train_precision = df['precision']
        train_recall = df['recall']
        val_accuracy = df['val_binary_accuracy']
        val_precision = df['val_precision']
        val_recall = df['val_recall']

        # Create the plot
        plt.figure(figsize=(8, 6))
        plt.plot(epochs, train_accuracy, label='Train Accuracy')
        plt.plot(epochs, train_precision, label='Train Precision')
        plt.plot(epochs, train_recall, label='Train Recall')
        plt.plot(epochs, val_accuracy, label='Validation Accuracy')
        plt.plot(epochs, val_precision, label='Validation Precision')
        plt.plot(epochs, val_recall, label='Validation Recall')

        # Set plot title and labels
        plot_name = report.split('_')[0] + '_metrics_plot.png'
        plt.title(f'Metrics History - {plot_name}')
        plt.xlabel('Epochs')
        plt.ylabel('Metrics')

        # Set plot legend
        plt.legend()

        # Save the plot
        plot_path = os.path.join(accuracy_plots_path, plot_name)
        plt.savefig(plot_path)

        # Display the plot (optional)
        plt.show()
        
def create_accuracy_loss_plots(folder_path, experimentId):
    """
    Creates plots for various metrics (accuracy, loss) for each epoch report in the specified folder.

    Args:
        folder_path (str): Path to the folder containing the epoch reports.

    Returns:
        None
    """
    # Get a list of all CSV files in the folder
    epoch_reports = [file for file in os.listdir(folder_path) if file.endswith('epochs_report.csv')]

    # Create the accuracy_plots directory if it doesn't exist
    accuracy_plots_path = os.path.join(folder_path, 'accuracy_plots')
    os.makedirs(accuracy_plots_path, exist_ok=True)

    # Cycle through the epoch reports and create plots
    for report in epoch_reports:
        # Read the epoch history CSV file
        report_path = os.path.join(folder_path, report)
        df = pd.read_csv(report_path)

        # Create the figure and subplots
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

        # Plot for the first subplot
        ax1.plot(df['binary_accuracy'], label='Training Accuracy')
        ax1.plot(df['val_binary_accuracy'], label='Validation Accuracy')
        ax1.set_xlabel('Epoch')
        ax1.set_ylabel('Accuracy')
        ax1.set_title('Training and Validation Accuracy')
        ax1.legend()

        # Plot for the second subplot
        ax2.plot(df['loss'], label='Training Loss')
        ax2.plot(df['val_loss'], label='Validation Loss')
        ax2.set_xlabel('Epoch')
        ax2.set_ylabel('Loss')
        ax2.set_title('Training and Validation Loss')
        ax2.legend()

        # Add a title that spans over the two plots
        plot_name = report.split('_')[0] + '_metrics_plot.png'
        fig.suptitle(f'{experimentID}\nTraining History for {plot_name}\n', fontsize=16, fontweight='bold')

        # Adjust the spacing between subplots and the suptitle
        plt.subplots_adjust(top=0.85, wspace=0.3)

        # Save the plot
        plot_path = os.path.join(accuracy_plots_path, f'{plot_name}_report')
        plt.savefig(plot_path)

        # Display the plot (optional)
        plt.show()      

def create_model_image(model, output_dir, name = 'model', extension = 'png'):
    """
    Creates an image of a TensorFlow model's structure and saves it to the specified directory.

    Args:
        model: The TensorFlow model to visualize.
        output_dir: The directory where the model image should be saved.
        name: The name of the model image file. Default is 'model'.
        extension: The file extension for the model image file. Default is 'png'.

    Returns:
        None
    """
    if extension not in ['png', 'svg', 'pdf', 'jpg']:
        throw(f'Invalid file extension: {extension}')
        
    # Ensure the output directory exists
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Construct the full path for the output file
    output_file = os.path.join(output_dir, f'{name}.{extension}')

    # Generate and save the model image
    plot_model(model, to_file=output_file, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ---
# # Experiments
# ---
# ## Experiment #BMS-0001 | Initial Model Selection
# **Experiment ID:** #BMS-0001
# **Experiment Description:** Initial test were performed on the selected base models (Xception, Inception, Resnet, VGG16 and VGG19). We explored how each model generalized the datasets with and without data augmentation.

# %%
# Experiment ID:BMS-0001
experimentId = "BMS-0001"

# Load Directories (Leave alone unless specifying a different dataset)
experiment_train_directory = train_directory
experiment_test_directory = test_directory
experiment_directory = f"{experiment_base_directory}/{experimentId}"
experiment_results_directory = f"{experiment_directory}/results"
experiment_models_directory = f"{experiment_directory}/models"

# Create directories if they don't exist
os.makedirs(name=experiment_directory, exist_ok=True)
os.makedirs(name=experiment_models_directory, exist_ok=True)
os.makedirs(name=experiment_results_directory, exist_ok=True)

# Declare lists for report generation
accuracy_report = []

# Declare Test Configurations
test_configurations = [
    [Xception, xception_preprocess_input, 32, True],
    [Xception, xception_preprocess_input, 32, False],
    [InceptionV3, inception_v3_preprocess_input, 32, True],
    [InceptionV3, inception_v3_preprocess_input, 32, False],
    [ResNet50, resnet50_preprocess_input, 32, True],
    [ResNet50, resnet50_preprocess_input, 32, False],
    [VGG16, vgg16_preprocess_input, 16, True],
    [VGG16, vgg16_preprocess_input, 16, False],
    [VGG19, vgg19_preprocess_input, 16, True],
    [VGG19, vgg19_preprocess_input, 16, False],
]

# Define Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    patience=3
)

# Define Reduce Learning Rate on Plateau Callback
lr_reducer = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=2,
    verbose=1,
)

# Loop through all combinations of models and trainable layers
for pretrained_model, preprocessing_function, batchSize, isAugmented in test_configurations:
    K.clear_session()

    # Setup Model Check Pointing
    nameSuffix = 'augmented' if isAugmented == True else 'not_augmented'
    model_checkpoint = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}.h5",
        monitor='val_loss',
        mode='min',
        verbose=1,
        save_best_only=True
    )

    # Create a dataset and preprocess images to suit base model
    train_ds, val_ds = create_train_val_datasets(preprocessing_function, experiment_train_directory, batch_size=batchSize, augment_data=isAugmented)
    test_ds = create_test_dataset(preprocessing_function, experiment_test_directory, batch_size=batchSize)

    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))

    # Create the base model from the pre-trained model
    base_model = pretrained_model(
        weights="imagenet", 
        include_top=False,
        input_tensor=inputs)

    # Base Model Frozen
    base_model.trainable = False

    # Add a classification head
    top_model = base_model(inputs, training=False)
    top_model = Conv2D(2048, (3, 3), padding='same')(top_model)
    top_model = BatchNormalization()(top_model)
    top_model = Activation('relu')(top_model)
    top_model = MaxPooling2D(pool_size=(2, 2))(top_model)

    top_model = Conv2D(2048, (3, 3), padding='same')(top_model)
    top_model = BatchNormalization()(top_model)
    top_model = Activation('relu')(top_model)
    top_model = MaxPooling2D(pool_size=(2, 2))(top_model)

    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation='relu')(top_model)
    top_model = BatchNormalization()(top_model)
    top_model = Dropout(0.8)(top_model)

    top_model = Dense(1024, activation='relu')(top_model)
    top_model = BatchNormalization()(top_model)
    top_model = Dropout(0.8)(top_model)

    top_model = Dense(1, activation='sigmoid')(top_model)

    model = Model(inputs=base_model.input, outputs=top_model)

    # Compile the model
    model.compile(
        optimizer=Adam(0.01),  
        loss=BinaryCrossentropy(from_logits=False),
        metrics=[BinaryAccuracy(), Precision(), Recall(), AUC()]
    )

    # Create Model Image
    create_model_image(model, experiment_models_directory, name = f'{pretrained_model.__name__}_model', extension = 'png')

    # Start Timer to measure processing time 
    start_time = time.time()

    # Train the model but first clear history (Required to append results without errors)
    history = model.fit(
        train_ds, 
        steps_per_epoch=train_ds.samples // train_ds.batch_size,
        epochs=15, 
        validation_data=test_ds,
        validation_steps=test_ds.samples // test_ds.batch_size,
        callbacks = [early_stopping, lr_reducer, model_checkpoint]
    )

    # End Timer and calculate processing time
    end_time = time.time()
    processing_time = end_time - start_time

    # Evaluate the model
    evaluate = model.evaluate(test_ds, steps = test_ds.samples // test_ds.batch_size, verbose=1)

    # Append results to accuracy_test list
    history_key = list(history.history.keys()) # As names of metric names can be dynamic, we need to get the keys of the history object
    accuracy_report.append({
        'Base Model': pretrained_model.__name__,
        'data_augmentation': isAugmented,
        'duration': round(processing_time, 3),
        'test_accuracy': round(evaluate[1], 3),
        'test_precision': round(evaluate[2], 3),
        'test_recall': round(evaluate[3], 3),
        'test_loss': round(evaluate[0], 3),
        'train_accuracy': round(history.history[history_key[1]][-1],3),
        'train_precision': round(history.history[history_key[2]][-1],3),
        'train_recall': round(history.history[history_key[3]][-1],3),
        'train_auc' : round(history.history[history_key[4]][-1],3),
        'train_loss': round(history.history[history_key[0]][-1],3),
        'val_accuracy': round(history.history[history_key[6]][-1],3),
        'val_precision': round(history.history[history_key[7]][-1],3),
        'val_recall': round(history.history[history_key[8]][-1],3),
        'val_auc' : round(history.history[history_key[9]][-1],3),
        'val_loss': round(history.history[history_key[5]][-1],3)
    })

    epochs_report = pd.DataFrame(history.history)
    epochs_report.to_csv(f"{experiment_results_directory}/{pretrained_model.__name__}_{nameSuffix}_epochs_report.csv", index=False)

# Create DataFrame with accuracy score and export as .csv
accuracy_test_results = pd.DataFrame(accuracy_report)
accuracy_test_results.to_csv(f'{experiment_results_directory}/accuracy_test_results.csv', index=False)

# Generate graphs from epochs_reports.csv and output to results folder.
create_accuracy_plots(f"{experiment_results_directory}")
create_all_metrics_plots(f"{experiment_results_directory}")
# Out:
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# 2023-06-01 14:48:08.175804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 14:48:08.176264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 14:48:08.176653: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 14:48:08.532579: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 14:48:08.532864: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 14:48:08.533108: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-01 14:48:08.533328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:09:00.0, compute capability: 8.6
# Epoch 1/15
# 2023-06-01 14:48:09.212089: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-01 14:48:10.887616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-01 14:48:12.130486: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-01 14:48:12.135185: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x56335ba35720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-01 14:48:12.135196: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2023-06-01 14:48:12.137795: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-01 14:48:12.214381: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2414/2414 [==============================] - ETA: 0s - loss: 1.0633 - binary_accuracy: 0.5333 - precision: 0.5197 - recall: 0.5071 - auc: 0.5334
# 2023-06-01 14:55:21.456098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.80985, saving model to ../experiments/base-model-selection/BMS-0001/models/VGG16_model_augmented.h5
# 2414/2414 [==============================] - 471s 193ms/step - loss: 1.0633 - binary_accuracy: 0.5333 - precision: 0.5197 - recall: 0.5071 - auc: 0.5334 - val_loss: 0.8099 - val_binary_accuracy: 0.5563 - val_precision: 0.7456 - val_recall: 0.1320 - val_auc: 0.6437 - lr: 0.0100
# Epoch 2/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6580 - binary_accuracy: 0.6296 - precision: 0.6231 - recall: 0.5990 - auc: 0.6782
# Epoch 2: val_loss improved from 0.80985 to 0.68198, saving model to ../experiments/base-model-selection/BMS-0001/models/VGG16_model_augmented.h5
# 2414/2414 [==============================] - 453s 188ms/step - loss: 0.6580 - binary_accuracy: 0.6296 - precision: 0.6231 - recall: 0.5990 - auc: 0.6782 - val_loss: 0.6820 - val_binary_accuracy: 0.6191 - val_precision: 0.6454 - val_recall: 0.4804 - val_auc: 0.6741 - lr: 0.0100
# Epoch 3/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6714 - binary_accuracy: 0.6376 - precision: 0.6294 - recall: 0.6161 - auc: 0.6882
# Epoch 3: val_loss did not improve from 0.68198
# 2414/2414 [==============================] - 473s 196ms/step - loss: 0.6714 - binary_accuracy: 0.6376 - precision: 0.6294 - recall: 0.6161 - auc: 0.6882 - val_loss: 0.7774 - val_binary_accuracy: 0.5898 - val_precision: 0.6628 - val_recall: 0.3176 - val_auc: 0.6660 - lr: 0.0100
# Epoch 4/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6573 - binary_accuracy: 0.6528 - precision: 0.6449 - recall: 0.6335 - auc: 0.7079
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 4: val_loss did not improve from 0.68198
# 2414/2414 [==============================] - 462s 191ms/step - loss: 0.6573 - binary_accuracy: 0.6528 - precision: 0.6449 - recall: 0.6335 - auc: 0.7079 - val_loss: 0.8230 - val_binary_accuracy: 0.6032 - val_precision: 0.5608 - val_recall: 0.8453 - val_auc: 0.6906 - lr: 0.0100
# Epoch 5/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.5514 - binary_accuracy: 0.7235 - precision: 0.7135 - recall: 0.7194 - auc: 0.7976
# Epoch 5: val_loss improved from 0.68198 to 0.67035, saving model to ../experiments/base-model-selection/BMS-0001/models/VGG16_model_augmented.h5
# 2414/2414 [==============================] - 470s 195ms/step - loss: 0.5514 - binary_accuracy: 0.7235 - precision: 0.7135 - recall: 0.7194 - auc: 0.7976 - val_loss: 0.6703 - val_binary_accuracy: 0.6574 - val_precision: 0.6357 - val_recall: 0.6904 - val_auc: 0.7184 - lr: 0.0050
# Epoch 6/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.5147 - binary_accuracy: 0.7545 - precision: 0.7440 - recall: 0.7535 - auc: 0.8300
# Epoch 6: val_loss did not improve from 0.67035
# 2414/2414 [==============================] - 468s 194ms/step - loss: 0.5147 - binary_accuracy: 0.7545 - precision: 0.7440 - recall: 0.7535 - auc: 0.8300 - val_loss: 0.7406 - val_binary_accuracy: 0.6705 - val_precision: 0.6659 - val_recall: 0.6462 - val_auc: 0.7289 - lr: 0.0050
# Epoch 7/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.4774 - binary_accuracy: 0.7817 - precision: 0.7696 - recall: 0.7854 - auc: 0.8579
# Epoch 7: val_loss improved from 0.67035 to 0.65921, saving model to ../experiments/base-model-selection/BMS-0001/models/VGG16_model_augmented.h5
# 2414/2414 [==============================] - 461s 191ms/step - loss: 0.4774 - binary_accuracy: 0.7817 - precision: 0.7696 - recall: 0.7854 - auc: 0.8579 - val_loss: 0.6592 - val_binary_accuracy: 0.6722 - val_precision: 0.6910 - val_recall: 0.5890 - val_auc: 0.7308 - lr: 0.0050
# Epoch 8/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.4510 - binary_accuracy: 0.7929 - precision: 0.7824 - recall: 0.7943 - auc: 0.8735
# Epoch 8: val_loss did not improve from 0.65921
# 2414/2414 [==============================] - 460s 190ms/step - loss: 0.4510 - binary_accuracy: 0.7929 - precision: 0.7824 - recall: 0.7943 - auc: 0.8735 - val_loss: 0.6899 - val_binary_accuracy: 0.6635 - val_precision: 0.7096 - val_recall: 0.5212 - val_auc: 0.7399 - lr: 0.0050
# Epoch 9/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.4176 - binary_accuracy: 0.8196 - precision: 0.8092 - recall: 0.8223 - auc: 0.8935
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
#
# Epoch 9: val_loss did not improve from 0.65921
# 2414/2414 [==============================] - 459s 190ms/step - loss: 0.4176 - binary_accuracy: 0.8196 - precision: 0.8092 - recall: 0.8223 - auc: 0.8935 - val_loss: 0.7613 - val_binary_accuracy: 0.6746 - val_precision: 0.7480 - val_recall: 0.4983 - val_auc: 0.7559 - lr: 0.0050
# Epoch 10/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.3624 - binary_accuracy: 0.8445 - precision: 0.8333 - recall: 0.8495 - auc: 0.9193
# Epoch 10: val_loss did not improve from 0.65921
# 2414/2414 [==============================] - 459s 190ms/step - loss: 0.3624 - binary_accuracy: 0.8445 - precision: 0.8333 - recall: 0.8495 - auc: 0.9193 - val_loss: 0.8061 - val_binary_accuracy: 0.6832 - val_precision: 0.7084 - val_recall: 0.5919 - val_auc: 0.7542 - lr: 0.0025
# Epoch 10: early stopping
#   2/534 [..............................] - ETA: 35s - loss: 0.9267 - binary_accuracy: 0.6250 - precision: 0.7059 - recall: 0.6316 - auc: 0.6640
# 2023-06-01 16:05:25.175744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 534/534 [==============================] - 36s 67ms/step - loss: 0.8055 - binary_accuracy: 0.6834 - precision: 0.7085 - recall: 0.5923 - auc: 0.7544
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# Epoch 1/15
# 2023-06-01 16:06:02.162419: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2414/2414 [==============================] - ETA: 0s - loss: 1.0405 - binary_accuracy: 0.5563 - precision: 0.5437 - recall: 0.5340 - auc: 0.5707
# 2023-06-01 16:09:12.850212: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.69195, saving model to ../experiments/base-model-selection/BMS-0001/models/VGG16_model_not_augmented.h5
# 2414/2414 [==============================] - 227s 93ms/step - loss: 1.0405 - binary_accuracy: 0.5563 - precision: 0.5437 - recall: 0.5340 - auc: 0.5707 - val_loss: 0.6920 - val_binary_accuracy: 0.5961 - val_precision: 0.5674 - val_recall: 0.7089 - val_auc: 0.6413 - lr: 0.0100
# Epoch 2/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.5317 - binary_accuracy: 0.7433 - precision: 0.7335 - recall: 0.7399 - auc: 0.8173
# Epoch 2: val_loss did not improve from 0.69195
# 2414/2414 [==============================] - 224s 93ms/step - loss: 0.5317 - binary_accuracy: 0.7433 - precision: 0.7335 - recall: 0.7399 - auc: 0.8173 - val_loss: 0.7834 - val_binary_accuracy: 0.6456 - val_precision: 0.6484 - val_recall: 0.5909 - val_auc: 0.7089 - lr: 0.0100
# Epoch 3/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.4766 - binary_accuracy: 0.7865 - precision: 0.7770 - recall: 0.7857 - auc: 0.8648
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 3: val_loss did not improve from 0.69195
# 2414/2414 [==============================] - 226s 94ms/step - loss: 0.4766 - binary_accuracy: 0.7865 - precision: 0.7770 - recall: 0.7857 - auc: 0.8648 - val_loss: 0.9600 - val_binary_accuracy: 0.6282 - val_precision: 0.5789 - val_recall: 0.8625 - val_auc: 0.7304 - lr: 0.0100
# Epoch 4/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2765 - binary_accuracy: 0.8886 - precision: 0.8835 - recall: 0.8874 - auc: 0.9539
# Epoch 4: val_loss did not improve from 0.69195
# 2414/2414 [==============================] - 225s 93ms/step - loss: 0.2765 - binary_accuracy: 0.8886 - precision: 0.8835 - recall: 0.8874 - auc: 0.9539 - val_loss: 0.9838 - val_binary_accuracy: 0.6660 - val_precision: 0.7283 - val_recall: 0.4984 - val_auc: 0.7289 - lr: 0.0050
# Epoch 4: early stopping
#   2/534 [..............................] - ETA: 36s - loss: 1.4870 - binary_accuracy: 0.5312 - precision: 0.5556 - recall: 0.3125 - auc: 0.6035
# 2023-06-01 16:21:04.685052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 534/534 [==============================] - 36s 68ms/step - loss: 0.9843 - binary_accuracy: 0.6660 - precision: 0.7287 - recall: 0.4986 - auc: 0.7289
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# Epoch 1/15
# 2023-06-01 16:21:42.253502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2414/2414 [==============================] - ETA: 0s - loss: 1.0839 - binary_accuracy: 0.5185 - precision: 0.5041 - recall: 0.4910 - auc: 0.5192
# 2023-06-01 16:28:45.985057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.71106, saving model to ../experiments/base-model-selection/BMS-0001/models/VGG19_model_augmented.h5
# 2414/2414 [==============================] - 466s 192ms/step - loss: 1.0839 - binary_accuracy: 0.5185 - precision: 0.5041 - recall: 0.4910 - auc: 0.5192 - val_loss: 0.7111 - val_binary_accuracy: 0.5432 - val_precision: 0.5284 - val_recall: 0.5555 - val_auc: 0.5710 - lr: 0.0100
# Epoch 2/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6830 - binary_accuracy: 0.5949 - precision: 0.5870 - recall: 0.5576 - auc: 0.6341
# Epoch 2: val_loss did not improve from 0.71106
# 2414/2414 [==============================] - 466s 193ms/step - loss: 0.6830 - binary_accuracy: 0.5949 - precision: 0.5870 - recall: 0.5576 - auc: 0.6341 - val_loss: 0.8412 - val_binary_accuracy: 0.5802 - val_precision: 0.5509 - val_recall: 0.7360 - val_auc: 0.6175 - lr: 0.0100
# Epoch 3/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6778 - binary_accuracy: 0.6305 - precision: 0.6212 - recall: 0.6114 - auc: 0.6792
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 3: val_loss did not improve from 0.71106
# 2414/2414 [==============================] - 465s 193ms/step - loss: 0.6778 - binary_accuracy: 0.6305 - precision: 0.6212 - recall: 0.6114 - auc: 0.6792 - val_loss: 0.8471 - val_binary_accuracy: 0.5296 - val_precision: 0.6939 - val_recall: 0.0573 - val_auc: 0.6337 - lr: 0.0100
# Epoch 4/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.5903 - binary_accuracy: 0.6944 - precision: 0.6852 - recall: 0.6851 - auc: 0.7594
# Epoch 4: val_loss did not improve from 0.71106
# 2414/2414 [==============================] - 472s 196ms/step - loss: 0.5903 - binary_accuracy: 0.6944 - precision: 0.6852 - recall: 0.6851 - auc: 0.7594 - val_loss: 0.7129 - val_binary_accuracy: 0.6360 - val_precision: 0.6283 - val_recall: 0.6146 - val_auc: 0.6863 - lr: 0.0050
# Epoch 4: early stopping
#   1/534 [..............................] - ETA: 1:07 - loss: 0.6534 - binary_accuracy: 0.7500 - precision: 0.6000 - recall: 0.6000 - auc: 0.6545
# 2023-06-01 16:52:50.921475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 534/534 [==============================] - 42s 78ms/step - loss: 0.7123 - binary_accuracy: 0.6366 - precision: 0.6289 - recall: 0.6148 - auc: 0.6868
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# Epoch 1/15
# 2023-06-01 16:53:33.939140: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2414/2414 [==============================] - ETA: 0s - loss: 1.0108 - binary_accuracy: 0.5954 - precision: 0.5839 - recall: 0.5797 - auc: 0.6154
# 2023-06-01 16:57:07.513402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.72787, saving model to ../experiments/base-model-selection/BMS-0001/models/VGG19_model_not_augmented.h5
# 2414/2414 [==============================] - 256s 105ms/step - loss: 1.0108 - binary_accuracy: 0.5954 - precision: 0.5839 - recall: 0.5797 - auc: 0.6154 - val_loss: 0.7279 - val_binary_accuracy: 0.6117 - val_precision: 0.5895 - val_recall: 0.6600 - val_auc: 0.6602 - lr: 0.0100
# Epoch 2/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.5218 - binary_accuracy: 0.7538 - precision: 0.7433 - recall: 0.7527 - auc: 0.8268
# Epoch 2: val_loss did not improve from 0.72787
# 2414/2414 [==============================] - 253s 105ms/step - loss: 0.5218 - binary_accuracy: 0.7538 - precision: 0.7433 - recall: 0.7527 - auc: 0.8268 - val_loss: 1.0201 - val_binary_accuracy: 0.5856 - val_precision: 0.7053 - val_recall: 0.2520 - val_auc: 0.6870 - lr: 0.0100
# Epoch 3/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.4676 - binary_accuracy: 0.7932 - precision: 0.7843 - recall: 0.7917 - auc: 0.8716
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 3: val_loss did not improve from 0.72787
# 2414/2414 [==============================] - 251s 104ms/step - loss: 0.4676 - binary_accuracy: 0.7932 - precision: 0.7843 - recall: 0.7917 - auc: 0.8716 - val_loss: 1.2199 - val_binary_accuracy: 0.6268 - val_precision: 0.6977 - val_recall: 0.4092 - val_auc: 0.6991 - lr: 0.0100
# Epoch 4/15
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2945 - binary_accuracy: 0.8801 - precision: 0.8759 - recall: 0.8771 - auc: 0.9478
# Epoch 4: val_loss did not improve from 0.72787
# 2414/2414 [==============================] - 248s 103ms/step - loss: 0.2945 - binary_accuracy: 0.8801 - precision: 0.8759 - recall: 0.8771 - auc: 0.9478 - val_loss: 1.0338 - val_binary_accuracy: 0.6470 - val_precision: 0.6075 - val_recall: 0.7729 - val_auc: 0.7242 - lr: 0.0050
# Epoch 4: early stopping
#   1/534 [..............................] - ETA: 1:09 - loss: 0.7597 - binary_accuracy: 0.7500 - precision: 0.8000 - recall: 0.8000 - auc: 0.8333
# 2023-06-01 17:10:22.062391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 534/534 [==============================] - 41s 77ms/step - loss: 1.0332 - binary_accuracy: 0.6472 - precision: 0.6077 - recall: 0.7731 - auc: 0.7244

# %% [markdown]
# ----
# ## Experiment #BMS-0002 | Xception Fine-Tuning
# **Experiment ID:** #BMS-0002
# **Experiment Description:**  Continuation of experiment BMS-0001, We load the pretrained models from the previous experiment and unfreeze the last 15 layers of the base model. The experiment we use Xception with data augmentation enabled.
#
# **Experiment Outcome:**
# **Next Test:**

# %%
# Experiment ID:BMS-0002
experimentId = "BMS-0002"

# Load Directories (Leave alone unless specifying a different dataset)
experiment_train_directory = train_directory
experiment_test_directory = test_directory
experiment_directory = f"{experiment_base_directory}/{experimentId}"
experiment_results_directory = f"{experiment_directory}/results"
experiment_models_directory = f"{experiment_directory}/models"
experiment_load_model_directory = "../experiments/base-model-selection/BMS-0001/models"

# Create directories if they don't exist
os.makedirs(name=experiment_directory, exist_ok=True)
os.makedirs(name=experiment_models_directory, exist_ok=True)
os.makedirs(name=experiment_results_directory, exist_ok=True)

# Declare lists for report generation
accuracy_report = []

# Declare Test Configurations
test_configurations = [
    [Xception, xception_preprocess_input, 32, True],
]

# Declare accuracy_test list
accuracy_test = []

# Define Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    patience=8
)

# Define Reduce Learning Rate on Plateau Callback
lr_reducer = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    verbose=1,
)

# Loop through all combinations of models and trainable layers
for pretrained_model, preprocessing_function, batch_size, is_augmented in test_configurations:
    # Clear Session
    K.clear_session()
    
    # Setup Model Check Pointing
    
    nameSuffix = 'augmented' if is_augmented == True else 'not_augmented'
    model_checkpoint_vl = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_vl.h5",
        monitor='val_loss',
        mode='min',
        verbose=1,
        save_best_only=True
    )
    
    model_checkpoint_ba = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_ba.h5",
        monitor='val_binary_accuracy',
        mode='max',
        verbose=1,
        save_best_only=True
    )
    
    # Create a dataset and preprocess images to suit base model
    train_ds, val_ds = create_train_val_datasets(preprocessing_function, experiment_train_directory, batch_size=batch_size, augment_data=is_augmented)
    test_ds = create_test_dataset(preprocessing_function, experiment_test_directory, batch_size=batch_size)

    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))


    #####################################################################################################################################
    # Load Previous Model and Weights
    #####################################################################################################################################

    # Load Model
    model = keras.models.load_model(
        f"{experiment_load_model_directory}/{pretrained_model.__name__}_model_{nameSuffix}.h5",
    )
    
    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))

    # Base model is the second layer in the model
    base_model = model.layers[1]

    # Make Base Model Trainable
    base_model.trainable = True

    # Freeze the base model (do not train everything but last 15 layers)
    for layer in base_model.layers[:-15]:
        layer.trainable = False

    # Hookup Previous Model Layers to New Model
    inputs = keras.Input(shape=(299, 299, 3))
    x = base_model(inputs, training=False)
    
    # Traverse the layers and connect them
    for layer in model.layers[2:]:
        x = layer(x)
    
    # Define the model
    model = keras.Model(inputs=inputs, outputs=x)

    model.summary()
    # Compile the model
    model.compile(
        optimizer=Adam(1e-4),  
        loss=BinaryCrossentropy(from_logits=False),
        metrics=[BinaryAccuracy(), Precision(), Recall(), AUC()]
    )
    
    #####################################################################################################################################
    # Begin Fine Tuning Entire Model
    #####################################################################################################################################
    
    # Start Timer to measure processing time 
    start_time = time.time()

    # Train the model
    history = model.fit(
        train_ds, 
        steps_per_epoch=train_ds.samples // train_ds.batch_size,
        epochs=50, 
        validation_data=test_ds,
        validation_steps=test_ds.samples // test_ds.batch_size,
        callbacks = [early_stopping, lr_reducer, model_checkpoint_vl, model_checkpoint_ba]
    )
    
    # End Timer and calculate processing time
    end_time = time.time()
    processing_time = end_time - start_time

    # Evaluate the model
    evaluate = model.evaluate(test_ds, steps = test_ds.samples // test_ds.batch_size, verbose=1)

    # Append results to accuracy_test list
    history_key = list(history.history.keys()) # As names of metric names can be dynamic, we need to get the keys of the history object
    accuracy_test.append({
        'Base Model': pretrained_model.__name__,
        'duration': round(processing_time, 3),
        'test_accuracy': round(evaluate[1], 3),
        'test_precision': round(evaluate[2], 3),
        'test_recall': round(evaluate[3], 3),
        'test_loss': round(evaluate[0], 3),
        'train_accuracy': round(history.history[history_key[1]][-1],3),
        'train_precision': round(history.history[history_key[2]][-1],3),
        'train_recall': round(history.history[history_key[3]][-1],3),
        'train_auc' : round(history.history[history_key[4]][-1],3),
        'train_loss': round(history.history[history_key[0]][-1],3),
        'val_accuracy': round(history.history[history_key[6]][-1],3),
        'val_precision': round(history.history[history_key[7]][-1],3),
        'val_recall': round(history.history[history_key[8]][-1],3),
        'val_auc' : round(history.history[history_key[9]][-1],3),
        'val_loss': round(history.history[history_key[5]][-1],3)
    })
    
    epochs_report = pd.DataFrame(history.history)
    epochs_report.to_csv(f"{experiment_results_directory}/{pretrained_model.__name__}_epochs_report.csv", index=False)
    
    model.save(f"{experiment_models_directory}/{pretrained_model.__name__}_finetuned_model_{nameSuffix}.h5")

# Create DataFrame with accuracy score and export as .csv
accuracy_test_results = pd.DataFrame(accuracy_test)
accuracy_test_results.to_csv(f'{experiment_results_directory}/accuracy_test_results.csv', index=False)

# Generate graphs from epochs_reports.csv and output to results folder.
create_accuracy_plots(f"{experiment_results_directory}")
create_all_metrics_plots(f"{experiment_results_directory}")
# Out:
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 2048)      37750784
#
#  batch_normalization_4 (Batc  (None, 10, 10, 2048)     8192
#  hNormalization)
#
#  activation (Activation)     (None, 10, 10, 2048)      0
#
#  max_pooling2d (MaxPooling2D  (None, 5, 5, 2048)       0
#  )
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 2048)        37750784
#
#  batch_normalization_5 (Batc  (None, 5, 5, 2048)       8192
#  hNormalization)
#
#  activation_1 (Activation)   (None, 5, 5, 2048)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 2048)       0
#  2D)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  batch_normalization_6 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  batch_normalization_7 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 99,536,425
# Trainable params: 85,451,041
# Non-trainable params: 14,085,384
# _________________________________________________________________
# Epoch 1/50
# 2023-06-03 09:47:07.029143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 1207/1207 [==============================] - ETA: 0s - loss: 0.4661 - binary_accuracy: 0.7798 - precision: 0.7823 - recall: 0.7571 - auc: 0.8627
# 2023-06-03 09:54:36.246151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.41530, saving model to ../experiments/base-model-selection/BMS-0002/models/Xception_model_augmented_vl.h5
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.81191, saving model to ../experiments/base-model-selection/BMS-0002/models/Xception_model_augmented_ba.h5
# 1207/1207 [==============================] - 478s 388ms/step - loss: 0.4661 - binary_accuracy: 0.7798 - precision: 0.7823 - recall: 0.7571 - auc: 0.8627 - val_loss: 0.4153 - val_binary_accuracy: 0.8119 - val_precision: 0.7902 - val_recall: 0.8346 - val_auc: 0.8944 - lr: 1.0000e-04
# Epoch 2/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2985 - binary_accuracy: 0.8763 - precision: 0.8665 - recall: 0.8809 - auc: 0.9457
# Epoch 2: val_loss did not improve from 0.41530
#
# Epoch 2: val_binary_accuracy did not improve from 0.81191
# 1207/1207 [==============================] - 456s 378ms/step - loss: 0.2985 - binary_accuracy: 0.8763 - precision: 0.8665 - recall: 0.8809 - auc: 0.9457 - val_loss: 1.2470 - val_binary_accuracy: 0.6120 - val_precision: 0.5564 - val_recall: 0.9993 - val_auc: 0.9058 - lr: 1.0000e-04
# Epoch 3/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2301 - binary_accuracy: 0.9077 - precision: 0.9020 - recall: 0.9086 - auc: 0.9674
# Epoch 3: val_loss improved from 0.41530 to 0.35654, saving model to ../experiments/base-model-selection/BMS-0002/models/Xception_model_augmented_vl.h5
#
# Epoch 3: val_binary_accuracy improved from 0.81191 to 0.86213, saving model to ../experiments/base-model-selection/BMS-0002/models/Xception_model_augmented_ba.h5
# 1207/1207 [==============================] - 459s 380ms/step - loss: 0.2301 - binary_accuracy: 0.9077 - precision: 0.9020 - recall: 0.9086 - auc: 0.9674 - val_loss: 0.3565 - val_binary_accuracy: 0.8621 - val_precision: 0.8490 - val_recall: 0.8715 - val_auc: 0.9327 - lr: 1.0000e-04
# Epoch 4/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.1905 - binary_accuracy: 0.9241 - precision: 0.9194 - recall: 0.9247 - auc: 0.9777
# Epoch 4: val_loss did not improve from 0.35654
#
# Epoch 4: val_binary_accuracy did not improve from 0.86213
# 1207/1207 [==============================] - 468s 388ms/step - loss: 0.1905 - binary_accuracy: 0.9241 - precision: 0.9194 - recall: 0.9247 - auc: 0.9777 - val_loss: 0.6445 - val_binary_accuracy: 0.7779 - val_precision: 0.6934 - val_recall: 0.9735 - val_auc: 0.9327 - lr: 1.0000e-04
# Epoch 5/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.1664 - binary_accuracy: 0.9341 - precision: 0.9286 - recall: 0.9362 - auc: 0.9828
# Epoch 5: val_loss did not improve from 0.35654
#
# Epoch 5: val_binary_accuracy did not improve from 0.86213
# 1207/1207 [==============================] - 462s 383ms/step - loss: 0.1664 - binary_accuracy: 0.9341 - precision: 0.9286 - recall: 0.9362 - auc: 0.9828 - val_loss: 0.4523 - val_binary_accuracy: 0.8386 - val_precision: 0.9123 - val_recall: 0.7390 - val_auc: 0.9306 - lr: 1.0000e-04
# Epoch 6/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.1498 - binary_accuracy: 0.9414 - precision: 0.9372 - recall: 0.9424 - auc: 0.9860
# Epoch 6: val_loss did not improve from 0.35654
#
# Epoch 6: val_binary_accuracy improved from 0.86213 to 0.86903, saving model to ../experiments/base-model-selection/BMS-0002/models/Xception_model_augmented_ba.h5
# 1207/1207 [==============================] - 461s 382ms/step - loss: 0.1498 - binary_accuracy: 0.9414 - precision: 0.9372 - recall: 0.9424 - auc: 0.9860 - val_loss: 0.3754 - val_binary_accuracy: 0.8690 - val_precision: 0.8552 - val_recall: 0.8797 - val_auc: 0.9397 - lr: 1.0000e-04
# Epoch 7/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.1325 - binary_accuracy: 0.9496 - precision: 0.9470 - recall: 0.9494 - auc: 0.9890
# Epoch 7: val_loss did not improve from 0.35654
#
# Epoch 7: val_binary_accuracy did not improve from 0.86903
# 1207/1207 [==============================] - 452s 374ms/step - loss: 0.1325 - binary_accuracy: 0.9496 - precision: 0.9470 - recall: 0.9494 - auc: 0.9890 - val_loss: 0.3900 - val_binary_accuracy: 0.8542 - val_precision: 0.8584 - val_recall: 0.8382 - val_auc: 0.9328 - lr: 1.0000e-04
# Epoch 8/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.1250 - binary_accuracy: 0.9519 - precision: 0.9489 - recall: 0.9521 - auc: 0.9901
# Epoch 8: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 8: val_loss did not improve from 0.35654
#
# Epoch 8: val_binary_accuracy did not improve from 0.86903
# 1207/1207 [==============================] - 461s 382ms/step - loss: 0.1250 - binary_accuracy: 0.9519 - precision: 0.9489 - recall: 0.9521 - auc: 0.9901 - val_loss: 0.9777 - val_binary_accuracy: 0.7441 - val_precision: 0.6576 - val_recall: 0.9880 - val_auc: 0.9141 - lr: 1.0000e-04
# Epoch 9/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.0917 - binary_accuracy: 0.9664 - precision: 0.9649 - recall: 0.9658 - auc: 0.9945
# Epoch 9: val_loss did not improve from 0.35654
#
# Epoch 9: val_binary_accuracy did not improve from 0.86903
# 1207/1207 [==============================] - 470s 389ms/step - loss: 0.0917 - binary_accuracy: 0.9664 - precision: 0.9649 - recall: 0.9658 - auc: 0.9945 - val_loss: 0.4211 - val_binary_accuracy: 0.8684 - val_precision: 0.9301 - val_recall: 0.7885 - val_auc: 0.9448 - lr: 5.0000e-05
# Epoch 10/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.0825 - binary_accuracy: 0.9689 - precision: 0.9677 - recall: 0.9683 - auc: 0.9955
# Epoch 10: val_loss did not improve from 0.35654
#
# Epoch 10: val_binary_accuracy improved from 0.86903 to 0.87769, saving model to ../experiments/base-model-selection/BMS-0002/models/Xception_model_augmented_ba.h5
# 1207/1207 [==============================] - 466s 386ms/step - loss: 0.0825 - binary_accuracy: 0.9689 - precision: 0.9677 - recall: 0.9683 - auc: 0.9955 - val_loss: 0.4187 - val_binary_accuracy: 0.8777 - val_precision: 0.8354 - val_recall: 0.9321 - val_auc: 0.9468 - lr: 5.0000e-05
# Epoch 11/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.0764 - binary_accuracy: 0.9723 - precision: 0.9720 - recall: 0.9708 - auc: 0.9960
# Epoch 11: val_loss did not improve from 0.35654
#
# Epoch 11: val_binary_accuracy did not improve from 0.87769
# 1207/1207 [==============================] - 463s 383ms/step - loss: 0.0764 - binary_accuracy: 0.9723 - precision: 0.9720 - recall: 0.9708 - auc: 0.9960 - val_loss: 0.5424 - val_binary_accuracy: 0.8535 - val_precision: 0.7848 - val_recall: 0.9622 - val_auc: 0.9387 - lr: 5.0000e-05
# Epoch 11: early stopping
#   1/267 [..............................] - ETA: 50s - loss: 0.8334 - binary_accuracy: 0.8750 - precision: 0.8000 - recall: 0.9231 - auc: 0.9028
# 2023-06-03 11:12:03.505597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 267/267 [==============================] - 25s 95ms/step - loss: 0.5412 - binary_accuracy: 0.8537 - precision: 0.7851 - recall: 0.9622 - auc: 0.9389

# %% [markdown]
# ----
# ## Experiment #BMS-0003 | InceptionV3 Fine-Tuning
# **Experiment ID:** #BMS-0003
# **Experiment Description:**  Continuation of experiment BMS-0001, We load the pretrained models from the previous experiment and unfreeze the last 15 layers of the base model. The experiment we use Inception with data augmentation enabled.

# %%
# Experiment ID:BMS-0003
experimentId = "BMS-0003"

# Load Directories (Leave alone unless specifying a different dataset)
experiment_train_directory = train_directory
experiment_test_directory = test_directory
experiment_directory = f"{experiment_base_directory}/{experimentId}"
experiment_results_directory = f"{experiment_directory}/results"
experiment_models_directory = f"{experiment_directory}/models"
experiment_load_model_directory = "../experiments/base-model-selection/BMS-0001/models"

# Create directories if they don't exist
os.makedirs(name=experiment_directory, exist_ok=True)
os.makedirs(name=experiment_models_directory, exist_ok=True)
os.makedirs(name=experiment_results_directory, exist_ok=True)

# Declare lists for report generation
accuracy_report = []

# Declare Test Configurations
test_configurations = [
    [InceptionV3, inception_v3_preprocess_input, 32, True],
]

# Declare accuracy_test list
accuracy_test = []

# Define Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    patience=8
)

# Define Reduce Learning Rate on Plateau Callback
lr_reducer = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    verbose=1,
)

# Loop through all combinations of models and trainable layers
for pretrained_model, preprocessing_function, batch_size, is_augmented in test_configurations:
    # Clear Session
    K.clear_session()
    
    # Setup Model Check Pointing
    
    nameSuffix = 'augmented' if is_augmented == True else 'not_augmented'
    model_checkpoint_vl = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_vl.h5",
        monitor='val_loss',
        mode='min',
        verbose=1,
        save_best_only=True
    )
    
    model_checkpoint_ba = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_ba.h5",
        monitor='val_binary_accuracy',
        mode='max',
        verbose=1,
        save_best_only=True
    )
    
    # Create a dataset and preprocess images to suit base model
    train_ds, val_ds = create_train_val_datasets(preprocessing_function, experiment_train_directory, batch_size=batch_size, augment_data=is_augmented)
    test_ds = create_test_dataset(preprocessing_function, experiment_test_directory, batch_size=batch_size)

    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))


    #####################################################################################################################################
    # Load Previous Model and Weights
    #####################################################################################################################################

    # Load Model
    model = keras.models.load_model(
        f"{experiment_load_model_directory}/{pretrained_model.__name__}_model_{nameSuffix}.h5",
    )
    
    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))

    # Base model is the second layer in the model
    base_model = model.layers[1]

    # Make Base Model Trainable
    base_model.trainable = True

    # Freeze the base model (do not train everything but last 15 layers)
    for layer in base_model.layers[:-15]:
        layer.trainable = False

    # Hookup Previous Model Layers to New Model
    inputs = keras.Input(shape=(299, 299, 3))
    x = base_model(inputs, training=False)
    
    # Traverse the layers and connect them
    for layer in model.layers[2:]:
        x = layer(x)
    
    # Define the model
    model = keras.Model(inputs=inputs, outputs=x)

    model.summary()
    # Compile the model
    model.compile(
        optimizer=Adam(1e-4),  
        loss=BinaryCrossentropy(from_logits=False),
        metrics=[BinaryAccuracy(), Precision(), Recall(), AUC()]
    )
    
    #####################################################################################################################################
    # Begin Fine Tuning Entire Model
    #####################################################################################################################################
    
    # Start Timer to measure processing time 
    start_time = time.time()

    # Train the model
    history = model.fit(
        train_ds, 
        steps_per_epoch=train_ds.samples // train_ds.batch_size,
        epochs=50, 
        validation_data=test_ds,
        validation_steps=test_ds.samples // test_ds.batch_size,
        callbacks = [early_stopping, lr_reducer, model_checkpoint_vl, model_checkpoint_ba]
    )
    
    # End Timer and calculate processing time
    end_time = time.time()
    processing_time = end_time - start_time

    # Evaluate the model
    evaluate = model.evaluate(test_ds, steps = test_ds.samples // test_ds.batch_size, verbose=1)

    # Append results to accuracy_test list
    history_key = list(history.history.keys()) # As names of metric names can be dynamic, we need to get the keys of the history object
    accuracy_test.append({
        'Base Model': pretrained_model.__name__,
        'duration': round(processing_time, 3),
        'test_accuracy': round(evaluate[1], 3),
        'test_precision': round(evaluate[2], 3),
        'test_recall': round(evaluate[3], 3),
        'test_loss': round(evaluate[0], 3),
        'train_accuracy': round(history.history[history_key[1]][-1],3),
        'train_precision': round(history.history[history_key[2]][-1],3),
        'train_recall': round(history.history[history_key[3]][-1],3),
        'train_auc' : round(history.history[history_key[4]][-1],3),
        'train_loss': round(history.history[history_key[0]][-1],3),
        'val_accuracy': round(history.history[history_key[6]][-1],3),
        'val_precision': round(history.history[history_key[7]][-1],3),
        'val_recall': round(history.history[history_key[8]][-1],3),
        'val_auc' : round(history.history[history_key[9]][-1],3),
        'val_loss': round(history.history[history_key[5]][-1],3)
    })
    
    epochs_report = pd.DataFrame(history.history)
    epochs_report.to_csv(f"{experiment_results_directory}/{pretrained_model.__name__}_epochs_report.csv", index=False)
    
    model.save(f"{experiment_models_directory}/{pretrained_model.__name__}_finetuned_model_{nameSuffix}.h5")

# Create DataFrame with accuracy score and export as .csv
accuracy_test_results = pd.DataFrame(accuracy_test)
accuracy_test_results.to_csv(f'{experiment_results_directory}/accuracy_test_results.csv', index=False)

# Generate graphs from epochs_reports.csv and output to results folder.
create_accuracy_plots(f"{experiment_results_directory}")
create_all_metrics_plots(f"{experiment_results_directory}")
# Out:
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# 2023-06-02 16:50:44.163040: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:44.163387: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:44.163667: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:44.699732: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:44.700017: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:44.700265: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-02 16:50:44.700488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5488 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:09:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  conv2d_94 (Conv2D)          (None, 8, 8, 2048)        37750784
#
#  batch_normalization_94 (Bat  (None, 8, 8, 2048)       8192
#  chNormalization)
#
#  activation_94 (Activation)  (None, 8, 8, 2048)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 2048)       0
#  2D)
#
#  conv2d_95 (Conv2D)          (None, 4, 4, 2048)        37750784
#
#  batch_normalization_95 (Bat  (None, 4, 4, 2048)       8192
#  chNormalization)
#
#  activation_95 (Activation)  (None, 4, 4, 2048)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 2048)       0
#  2D)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  batch_normalization_96 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  batch_normalization_97 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 100,477,729
# Trainable params: 79,057,537
# Non-trainable params: 21,420,192
# _________________________________________________________________
# Epoch 1/50
# 2023-06-02 16:50:49.026601: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-02 16:50:52.727906: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-02 16:50:56.113919: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-02 16:50:56.132936: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x55d8e6d80880 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-02 16:50:56.132952: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2023-06-02 16:50:56.148873: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-02 16:50:56.298525: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1207/1207 [==============================] - ETA: 0s - loss: 0.3621 - binary_accuracy: 0.8427 - precision: 0.8310 - recall: 0.8483 - auc: 0.9188
# 2023-06-02 16:58:24.532757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.62672, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_vl.h5
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.72706, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_ba.h5
# 1207/1207 [==============================] - 483s 392ms/step - loss: 0.3621 - binary_accuracy: 0.8427 - precision: 0.8310 - recall: 0.8483 - auc: 0.9188 - val_loss: 0.6267 - val_binary_accuracy: 0.7271 - val_precision: 0.6890 - val_recall: 0.7988 - val_auc: 0.8099 - lr: 1.0000e-04
# Epoch 2/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.3336 - binary_accuracy: 0.8573 - precision: 0.8442 - recall: 0.8658 - auc: 0.9314
# Epoch 2: val_loss improved from 0.62672 to 0.60210, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_vl.h5
#
# Epoch 2: val_binary_accuracy improved from 0.72706 to 0.73525, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_ba.h5
# 1207/1207 [==============================] - 459s 380ms/step - loss: 0.3336 - binary_accuracy: 0.8573 - precision: 0.8442 - recall: 0.8658 - auc: 0.9314 - val_loss: 0.6021 - val_binary_accuracy: 0.7353 - val_precision: 0.7505 - val_recall: 0.6818 - val_auc: 0.8226 - lr: 1.0000e-04
# Epoch 3/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.3161 - binary_accuracy: 0.8661 - precision: 0.8534 - recall: 0.8744 - auc: 0.9385
# Epoch 3: val_loss did not improve from 0.60210
#
# Epoch 3: val_binary_accuracy improved from 0.73525 to 0.73759, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_ba.h5
# 1207/1207 [==============================] - 457s 378ms/step - loss: 0.3161 - binary_accuracy: 0.8661 - precision: 0.8534 - recall: 0.8744 - auc: 0.9385 - val_loss: 0.6327 - val_binary_accuracy: 0.7376 - val_precision: 0.7680 - val_recall: 0.6589 - val_auc: 0.8244 - lr: 1.0000e-04
# Epoch 4/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.3014 - binary_accuracy: 0.8705 - precision: 0.8589 - recall: 0.8774 - auc: 0.9442
# Epoch 4: val_loss did not improve from 0.60210
#
# Epoch 4: val_binary_accuracy improved from 0.73759 to 0.73982, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_ba.h5
# 1207/1207 [==============================] - 461s 382ms/step - loss: 0.3014 - binary_accuracy: 0.8705 - precision: 0.8589 - recall: 0.8774 - auc: 0.9442 - val_loss: 0.6590 - val_binary_accuracy: 0.7398 - val_precision: 0.8017 - val_recall: 0.6173 - val_auc: 0.8315 - lr: 1.0000e-04
# Epoch 5/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2874 - binary_accuracy: 0.8788 - precision: 0.8701 - recall: 0.8819 - auc: 0.9492
# Epoch 5: val_loss improved from 0.60210 to 0.58577, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_vl.h5
#
# Epoch 5: val_binary_accuracy improved from 0.73982 to 0.75831, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_ba.h5
# 1207/1207 [==============================] - 461s 382ms/step - loss: 0.2874 - binary_accuracy: 0.8788 - precision: 0.8701 - recall: 0.8819 - auc: 0.9492 - val_loss: 0.5858 - val_binary_accuracy: 0.7583 - val_precision: 0.7525 - val_recall: 0.7491 - val_auc: 0.8349 - lr: 1.0000e-04
# Epoch 6/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2797 - binary_accuracy: 0.8823 - precision: 0.8724 - recall: 0.8873 - auc: 0.9522
# Epoch 6: val_loss did not improve from 0.58577
#
# Epoch 6: val_binary_accuracy did not improve from 0.75831
# 1207/1207 [==============================] - 459s 380ms/step - loss: 0.2797 - binary_accuracy: 0.8823 - precision: 0.8724 - recall: 0.8873 - auc: 0.9522 - val_loss: 0.6225 - val_binary_accuracy: 0.7487 - val_precision: 0.7633 - val_recall: 0.7002 - val_auc: 0.8298 - lr: 1.0000e-04
# Epoch 7/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2690 - binary_accuracy: 0.8879 - precision: 0.8805 - recall: 0.8898 - auc: 0.9557
# Epoch 7: val_loss did not improve from 0.58577
#
# Epoch 7: val_binary_accuracy did not improve from 0.75831
# 1207/1207 [==============================] - 458s 379ms/step - loss: 0.2690 - binary_accuracy: 0.8879 - precision: 0.8805 - recall: 0.8898 - auc: 0.9557 - val_loss: 0.6359 - val_binary_accuracy: 0.7543 - val_precision: 0.7103 - val_recall: 0.8347 - val_auc: 0.8353 - lr: 1.0000e-04
# Epoch 8/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2656 - binary_accuracy: 0.8903 - precision: 0.8829 - recall: 0.8924 - auc: 0.9567
# Epoch 8: val_loss did not improve from 0.58577
#
# Epoch 8: val_binary_accuracy did not improve from 0.75831
# 1207/1207 [==============================] - 459s 380ms/step - loss: 0.2656 - binary_accuracy: 0.8903 - precision: 0.8829 - recall: 0.8924 - auc: 0.9567 - val_loss: 0.6363 - val_binary_accuracy: 0.7521 - val_precision: 0.7876 - val_recall: 0.6712 - val_auc: 0.8372 - lr: 1.0000e-04
# Epoch 9/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2560 - binary_accuracy: 0.8940 - precision: 0.8858 - recall: 0.8972 - auc: 0.9598
# Epoch 9: val_loss did not improve from 0.58577
#
# Epoch 9: val_binary_accuracy did not improve from 0.75831
# 1207/1207 [==============================] - 459s 380ms/step - loss: 0.2560 - binary_accuracy: 0.8940 - precision: 0.8858 - recall: 0.8972 - auc: 0.9598 - val_loss: 0.6519 - val_binary_accuracy: 0.7488 - val_precision: 0.8054 - val_recall: 0.6375 - val_auc: 0.8427 - lr: 1.0000e-04
# Epoch 10/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2497 - binary_accuracy: 0.8966 - precision: 0.8890 - recall: 0.8993 - auc: 0.9618
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 10: val_loss did not improve from 0.58577
#
# Epoch 10: val_binary_accuracy did not improve from 0.75831
# 1207/1207 [==============================] - 459s 380ms/step - loss: 0.2497 - binary_accuracy: 0.8966 - precision: 0.8890 - recall: 0.8993 - auc: 0.9618 - val_loss: 0.6322 - val_binary_accuracy: 0.7559 - val_precision: 0.7714 - val_recall: 0.7067 - val_auc: 0.8381 - lr: 1.0000e-04
# Epoch 11/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2273 - binary_accuracy: 0.9082 - precision: 0.9014 - recall: 0.9105 - auc: 0.9684
# Epoch 11: val_loss did not improve from 0.58577
#
# Epoch 11: val_binary_accuracy did not improve from 0.75831
# 1207/1207 [==============================] - 460s 381ms/step - loss: 0.2273 - binary_accuracy: 0.9082 - precision: 0.9014 - recall: 0.9105 - auc: 0.9684 - val_loss: 0.6370 - val_binary_accuracy: 0.7571 - val_precision: 0.7861 - val_recall: 0.6875 - val_auc: 0.8447 - lr: 5.0000e-05
# Epoch 12/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2287 - binary_accuracy: 0.9057 - precision: 0.8986 - recall: 0.9083 - auc: 0.9679
# Epoch 12: val_loss did not improve from 0.58577
#
# Epoch 12: val_binary_accuracy improved from 0.75831 to 0.76697, saving model to ../experiments/base-model-selection/BMS-0003/models/InceptionV3_model_augmented_ba.h5
# 1207/1207 [==============================] - 461s 382ms/step - loss: 0.2287 - binary_accuracy: 0.9057 - precision: 0.8986 - recall: 0.9083 - auc: 0.9679 - val_loss: 0.6098 - val_binary_accuracy: 0.7670 - val_precision: 0.7621 - val_recall: 0.7564 - val_auc: 0.8465 - lr: 5.0000e-05
# Epoch 13/50
# 1207/1207 [==============================] - ETA: 0s - loss: 0.2195 - binary_accuracy: 0.9091 - precision: 0.9020 - recall: 0.9116 - auc: 0.9705
# Epoch 13: val_loss did not improve from 0.58577
#
# Epoch 13: val_binary_accuracy did not improve from 0.76697
# 1207/1207 [==============================] - 459s 381ms/step - loss: 0.2195 - binary_accuracy: 0.9091 - precision: 0.9020 - recall: 0.9116 - auc: 0.9705 - val_loss: 0.6397 - val_binary_accuracy: 0.7618 - val_precision: 0.7891 - val_recall: 0.6957 - val_auc: 0.8468 - lr: 5.0000e-05
# Epoch 13: early stopping
#   1/267 [..............................] - ETA: 45s - loss: 0.3467 - binary_accuracy: 0.8125 - precision: 0.8000 - recall: 0.8000 - auc: 0.9373
# 2023-06-02 18:30:44.652762: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 267/267 [==============================] - 21s 78ms/step - loss: 0.6400 - binary_accuracy: 0.7618 - precision: 0.7893 - recall: 0.6956 - auc: 0.8468

# %% [markdown]
# ----
# ## Experiment #BMS-0004 | Resnet50 Fine-Tuning
# **Experiment ID:** #BMS-0004
# **Experiment Description:**  Continuation of experiment BMS-0001, We load the pretrained models from the previous experiment and unfreeze the last 15 layers of the base model. The experiment we use Resnet with data augmentation enabled.

# %%
# Experiment ID:BMS-0004
experimentId = "BMS-0004"

# Load Directories (Leave alone unless specifying a different dataset)
experiment_train_directory = train_directory
experiment_test_directory = test_directory
experiment_directory = f"{experiment_base_directory}/{experimentId}"
experiment_results_directory = f"{experiment_directory}/results"
experiment_models_directory = f"{experiment_directory}/models"
experiment_load_model_directory = "../experiments/base-model-selection/BMS-0001/models"

# Create directories if they don't exist
os.makedirs(name=experiment_directory, exist_ok=True)
os.makedirs(name=experiment_models_directory, exist_ok=True)
os.makedirs(name=experiment_results_directory, exist_ok=True)

# Declare lists for report generation
accuracy_report = []

# Declare Test Configurations
test_configurations = [
    [ResNet50, resnet50_preprocess_input, 16, True],
]

# Declare accuracy_test list
accuracy_test = []

# Define Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    patience=8
)

# Define Reduce Learning Rate on Plateau Callback
lr_reducer = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    verbose=1,
)

# Loop through all combinations of models and trainable layers
for pretrained_model, preprocessing_function, batch_size, is_augmented in test_configurations:
    # Clear Session
    K.clear_session()
    
    # Setup Model Check Pointing
    
    nameSuffix = 'augmented' if is_augmented == True else 'not_augmented'
    model_checkpoint_vl = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_vl.h5",
        monitor='val_loss',
        mode='min',
        verbose=1,
        save_best_only=True
    )
    
    model_checkpoint_ba = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_ba.h5",
        monitor='val_binary_accuracy',
        mode='max',
        verbose=1,
        save_best_only=True
    )
    
    # Create a dataset and preprocess images to suit base model
    train_ds, val_ds = create_train_val_datasets(preprocessing_function, experiment_train_directory, batch_size=batch_size, augment_data=is_augmented)
    test_ds = create_test_dataset(preprocessing_function, experiment_test_directory, batch_size=batch_size)

    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))


    #####################################################################################################################################
    # Load Previous Model and Weights
    #####################################################################################################################################

    # Load Model
    model = keras.models.load_model(
        f"{experiment_load_model_directory}/{pretrained_model.__name__}_model_{nameSuffix}.h5",
    )
    
    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))

    # Base model is the second layer in the model
    base_model = model.layers[1]

    # Make Base Model Trainable
    base_model.trainable = True

    # Freeze the base model (do not train everything but last 15 layers)
    for layer in base_model.layers[:-15]:
        layer.trainable = False

    # Hookup Previous Model Layers to New Model
    inputs = keras.Input(shape=(299, 299, 3))
    x = base_model(inputs, training=False)
    
    # Traverse the layers and connect them
    for layer in model.layers[2:]:
        x = layer(x)
    
    # Define the model
    model = keras.Model(inputs=inputs, outputs=x)

    model.summary()
    # Compile the model
    model.compile(
        optimizer=Adam(1e-4),  
        loss=BinaryCrossentropy(from_logits=False),
        metrics=[BinaryAccuracy(), Precision(), Recall(), AUC()]
    )
    
    #####################################################################################################################################
    # Begin Fine Tuning Entire Model
    #####################################################################################################################################
    
    # Start Timer to measure processing time 
    start_time = time.time()

    # Train the model
    history = model.fit(
        train_ds, 
        steps_per_epoch=train_ds.samples // train_ds.batch_size,
        epochs=50, 
        validation_data=test_ds,
        validation_steps=test_ds.samples // test_ds.batch_size,
        callbacks = [early_stopping, lr_reducer, model_checkpoint_vl, model_checkpoint_ba]
    )
    
    # End Timer and calculate processing time
    end_time = time.time()
    processing_time = end_time - start_time

    # Evaluate the model
    evaluate = model.evaluate(test_ds, steps = test_ds.samples // test_ds.batch_size, verbose=1)

    # Append results to accuracy_test list
    history_key = list(history.history.keys()) # As names of metric names can be dynamic, we need to get the keys of the history object
    accuracy_test.append({
        'Base Model': pretrained_model.__name__,
        'duration': round(processing_time, 3),
        'test_accuracy': round(evaluate[1], 3),
        'test_precision': round(evaluate[2], 3),
        'test_recall': round(evaluate[3], 3),
        'test_loss': round(evaluate[0], 3),
        'train_accuracy': round(history.history[history_key[1]][-1],3),
        'train_precision': round(history.history[history_key[2]][-1],3),
        'train_recall': round(history.history[history_key[3]][-1],3),
        'train_auc' : round(history.history[history_key[4]][-1],3),
        'train_loss': round(history.history[history_key[0]][-1],3),
        'val_accuracy': round(history.history[history_key[6]][-1],3),
        'val_precision': round(history.history[history_key[7]][-1],3),
        'val_recall': round(history.history[history_key[8]][-1],3),
        'val_auc' : round(history.history[history_key[9]][-1],3),
        'val_loss': round(history.history[history_key[5]][-1],3)
    })
    
    epochs_report = pd.DataFrame(history.history)
    epochs_report.to_csv(f"{experiment_results_directory}/{pretrained_model.__name__}_epochs_report.csv", index=False)
    
    model.save(f"{experiment_models_directory}/{pretrained_model.__name__}_finetuned_model_{nameSuffix}.h5")

# Create DataFrame with accuracy score and export as .csv
accuracy_test_results = pd.DataFrame(accuracy_test)
accuracy_test_results.to_csv(f'{experiment_results_directory}/accuracy_test_results.csv', index=False)

# Generate graphs from epochs_reports.csv and output to results folder.
create_accuracy_plots(f"{experiment_results_directory}")
create_all_metrics_plots(f"{experiment_results_directory}")
# Out:
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  conv2d (Conv2D)             (None, 10, 10, 2048)      37750784
#
#  batch_normalization (BatchN  (None, 10, 10, 2048)     8192
#  ormalization)
#
#  activation (Activation)     (None, 10, 10, 2048)      0
#
#  max_pooling2d (MaxPooling2D  (None, 5, 5, 2048)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 2048)        37750784
#
#  batch_normalization_1 (Batc  (None, 5, 5, 2048)       8192
#  hNormalization)
#
#  activation_1 (Activation)   (None, 5, 5, 2048)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 2048)       0
#  2D)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 102,262,657
# Trainable params: 84,183,041
# Non-trainable params: 18,079,616
# _________________________________________________________________
# Epoch 1/50
# 2023-06-01 20:51:58.470927: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2788 - binary_accuracy: 0.8862 - precision: 0.8823 - recall: 0.8833 - auc: 0.9526
# 2023-06-01 20:59:07.196358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.39792, saving model to ../experiments/base-model-selection/BMS-0004/models/ResNet50_model_augmented_vl.h5
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.83240, saving model to ../experiments/base-model-selection/BMS-0004/models/ResNet50_model_augmented_ba.h5
# 2414/2414 [==============================] - 463s 190ms/step - loss: 0.2788 - binary_accuracy: 0.8862 - precision: 0.8823 - recall: 0.8833 - auc: 0.9526 - val_loss: 0.3979 - val_binary_accuracy: 0.8324 - val_precision: 0.7957 - val_recall: 0.8819 - val_auc: 0.9195 - lr: 1.0000e-04
# Epoch 2/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2377 - binary_accuracy: 0.9046 - precision: 0.8990 - recall: 0.9052 - auc: 0.9652
# Epoch 2: val_loss improved from 0.39792 to 0.38159, saving model to ../experiments/base-model-selection/BMS-0004/models/ResNet50_model_augmented_vl.h5
#
# Epoch 2: val_binary_accuracy improved from 0.83240 to 0.84071, saving model to ../experiments/base-model-selection/BMS-0004/models/ResNet50_model_augmented_ba.h5
# 2414/2414 [==============================] - 460s 190ms/step - loss: 0.2377 - binary_accuracy: 0.9046 - precision: 0.8990 - recall: 0.9052 - auc: 0.9652 - val_loss: 0.3816 - val_binary_accuracy: 0.8407 - val_precision: 0.8299 - val_recall: 0.8457 - val_auc: 0.9244 - lr: 1.0000e-04
# Epoch 3/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2236 - binary_accuracy: 0.9102 - precision: 0.9058 - recall: 0.9096 - auc: 0.9692
# Epoch 3: val_loss did not improve from 0.38159
#
# Epoch 3: val_binary_accuracy improved from 0.84071 to 0.84398, saving model to ../experiments/base-model-selection/BMS-0004/models/ResNet50_model_augmented_ba.h5
# 2414/2414 [==============================] - 462s 191ms/step - loss: 0.2236 - binary_accuracy: 0.9102 - precision: 0.9058 - recall: 0.9096 - auc: 0.9692 - val_loss: 0.3905 - val_binary_accuracy: 0.8440 - val_precision: 0.8402 - val_recall: 0.8384 - val_auc: 0.9223 - lr: 1.0000e-04
# Epoch 4/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2052 - binary_accuracy: 0.9188 - precision: 0.9131 - recall: 0.9203 - auc: 0.9739
# Epoch 4: val_loss did not improve from 0.38159
#
# Epoch 4: val_binary_accuracy did not improve from 0.84398
# 2414/2414 [==============================] - 461s 191ms/step - loss: 0.2052 - binary_accuracy: 0.9188 - precision: 0.9131 - recall: 0.9203 - auc: 0.9739 - val_loss: 0.4287 - val_binary_accuracy: 0.8318 - val_precision: 0.8396 - val_recall: 0.8087 - val_auc: 0.9165 - lr: 1.0000e-04
# Epoch 5/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1971 - binary_accuracy: 0.9218 - precision: 0.9184 - recall: 0.9208 - auc: 0.9759
# Epoch 5: val_loss did not improve from 0.38159
#
# Epoch 5: val_binary_accuracy did not improve from 0.84398
# 2414/2414 [==============================] - 469s 194ms/step - loss: 0.1971 - binary_accuracy: 0.9218 - precision: 0.9184 - recall: 0.9208 - auc: 0.9759 - val_loss: 0.4317 - val_binary_accuracy: 0.8305 - val_precision: 0.8506 - val_recall: 0.7900 - val_auc: 0.9156 - lr: 1.0000e-04
# Epoch 6/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1843 - binary_accuracy: 0.9288 - precision: 0.9259 - recall: 0.9275 - auc: 0.9788
# Epoch 6: val_loss did not improve from 0.38159
#
# Epoch 6: val_binary_accuracy did not improve from 0.84398
# 2414/2414 [==============================] - 458s 190ms/step - loss: 0.1843 - binary_accuracy: 0.9288 - precision: 0.9259 - recall: 0.9275 - auc: 0.9788 - val_loss: 0.4257 - val_binary_accuracy: 0.8380 - val_precision: 0.8250 - val_recall: 0.8461 - val_auc: 0.9178 - lr: 1.0000e-04
# Epoch 7/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1826 - binary_accuracy: 0.9295 - precision: 0.9276 - recall: 0.9272 - auc: 0.9792
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 7: val_loss did not improve from 0.38159
#
# Epoch 7: val_binary_accuracy did not improve from 0.84398
# 2414/2414 [==============================] - 460s 190ms/step - loss: 0.1826 - binary_accuracy: 0.9295 - precision: 0.9276 - recall: 0.9272 - auc: 0.9792 - val_loss: 0.4089 - val_binary_accuracy: 0.8387 - val_precision: 0.8394 - val_recall: 0.8264 - val_auc: 0.9228 - lr: 1.0000e-04
# Epoch 8/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1549 - binary_accuracy: 0.9402 - precision: 0.9374 - recall: 0.9395 - auc: 0.9849
# Epoch 8: val_loss did not improve from 0.38159
#
# Epoch 8: val_binary_accuracy did not improve from 0.84398
# 2414/2414 [==============================] - 462s 191ms/step - loss: 0.1549 - binary_accuracy: 0.9402 - precision: 0.9374 - recall: 0.9395 - auc: 0.9849 - val_loss: 0.4520 - val_binary_accuracy: 0.8302 - val_precision: 0.7923 - val_recall: 0.8818 - val_auc: 0.9198 - lr: 5.0000e-05
# Epoch 9/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1493 - binary_accuracy: 0.9422 - precision: 0.9387 - recall: 0.9423 - auc: 0.9859
# Epoch 9: val_loss did not improve from 0.38159
#
# Epoch 9: val_binary_accuracy did not improve from 0.84398
# 2414/2414 [==============================] - 456s 189ms/step - loss: 0.1493 - binary_accuracy: 0.9422 - precision: 0.9387 - recall: 0.9423 - auc: 0.9859 - val_loss: 0.4262 - val_binary_accuracy: 0.8425 - val_precision: 0.8159 - val_recall: 0.8726 - val_auc: 0.9258 - lr: 5.0000e-05
# Epoch 10/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1457 - binary_accuracy: 0.9456 - precision: 0.9431 - recall: 0.9449 - auc: 0.9863
# Epoch 10: val_loss did not improve from 0.38159
#
# Epoch 10: val_binary_accuracy improved from 0.84398 to 0.84820, saving model to ../experiments/base-model-selection/BMS-0004/models/ResNet50_model_augmented_ba.h5
# 2414/2414 [==============================] - 454s 188ms/step - loss: 0.1457 - binary_accuracy: 0.9456 - precision: 0.9431 - recall: 0.9449 - auc: 0.9863 - val_loss: 0.4346 - val_binary_accuracy: 0.8482 - val_precision: 0.8407 - val_recall: 0.8482 - val_auc: 0.9236 - lr: 5.0000e-05
# Epoch 10: early stopping
#   2/534 [..............................] - ETA: 33s - loss: 0.2504 - binary_accuracy: 0.8750 - precision: 0.8571 - recall: 0.8571 - auc: 0.9643
# 2023-06-01 22:08:43.864377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 534/534 [==============================] - 32s 61ms/step - loss: 0.4359 - binary_accuracy: 0.8480 - precision: 0.8404 - recall: 0.8483 - auc: 0.9232

# %% [markdown]
# ----
# ## Experiment #BMS-0005 | VGG16 Fine-Tuning
# **Experiment ID:** #BMS-0005
# **Experiment Description:**  Continuation of experiment BMS-0001, We load the pretrained models from the previous experiment and unfreeze the last 15 layers of the base model. The experiment we use VGG16 with data augmentation enabled.

# %%
# Experiment ID:BMS-0005
experimentId = "BMS-0005"

# Load Directories (Leave alone unless specifying a different dataset)
experiment_train_directory = train_directory
experiment_test_directory = test_directory
experiment_directory = f"{experiment_base_directory}/{experimentId}"
experiment_results_directory = f"{experiment_directory}/results"
experiment_models_directory = f"{experiment_directory}/models"
experiment_load_model_directory = "../experiments/base-model-selection/BMS-0001/models"

# Create directories if they don't exist
os.makedirs(name=experiment_directory, exist_ok=True)
os.makedirs(name=experiment_models_directory, exist_ok=True)
os.makedirs(name=experiment_results_directory, exist_ok=True)

# Declare lists for report generation
accuracy_report = []

# Declare Test Configurations
test_configurations = [
    [VGG16, vgg16_preprocess_input, 16, True],
]

# Declare accuracy_test list
accuracy_test = []

# Define Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    patience=8
)

# Define Reduce Learning Rate on Plateau Callback
lr_reducer = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    verbose=1,
)

# Loop through all combinations of models and trainable layers
for pretrained_model, preprocessing_function, batch_size, is_augmented in test_configurations:
    # Clear Session
    K.clear_session()
    
    # Setup Model Check Pointing
    
    nameSuffix = 'augmented' if is_augmented == True else 'not_augmented'
    model_checkpoint_vl = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_vl.h5",
        monitor='val_loss',
        mode='min',
        verbose=1,
        save_best_only=True
    )
    
    model_checkpoint_ba = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_ba.h5",
        monitor='val_binary_accuracy',
        mode='max',
        verbose=1,
        save_best_only=True
    )
    
    # Create a dataset and preprocess images to suit base model
    train_ds, val_ds = create_train_val_datasets(preprocessing_function, experiment_train_directory, batch_size=batch_size, augment_data=is_augmented)
    test_ds = create_test_dataset(preprocessing_function, experiment_test_directory, batch_size=batch_size)

    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))


    #####################################################################################################################################
    # Load Previous Model and Weights
    #####################################################################################################################################

    # Load Model
    model = keras.models.load_model(
        f"{experiment_load_model_directory}/{pretrained_model.__name__}_model_{nameSuffix}.h5",
    )
    
    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))

    # Base model is the second layer in the model
    base_model = model.layers[1]

    # Make Base Model Trainable
    base_model.trainable = True

    # Freeze the base model (do not train everything but last 15 layers)
    for layer in base_model.layers[:-15]:
        layer.trainable = False

    # Hookup Previous Model Layers to New Model
    inputs = keras.Input(shape=(299, 299, 3))
    x = base_model(inputs, training=False)
    
    # Traverse the layers and connect them
    for layer in model.layers[2:]:
        x = layer(x)
    
    # Define the model
    model = keras.Model(inputs=inputs, outputs=x)

    model.summary()
    # Compile the model
    model.compile(
        optimizer=Adam(1e-4),  
        loss=BinaryCrossentropy(from_logits=False),
        metrics=[BinaryAccuracy(), Precision(), Recall(), AUC()]
    )
    
    #####################################################################################################################################
    # Begin Fine Tuning Entire Model
    #####################################################################################################################################
    
    # Start Timer to measure processing time 
    start_time = time.time()

    # Train the model
    history = model.fit(
        train_ds, 
        steps_per_epoch=train_ds.samples // train_ds.batch_size,
        epochs=50, 
        validation_data=test_ds,
        validation_steps=test_ds.samples // test_ds.batch_size,
        callbacks = [early_stopping, lr_reducer, model_checkpoint_vl, model_checkpoint_ba]
    )
    
    # End Timer and calculate processing time
    end_time = time.time()
    processing_time = end_time - start_time

    # Evaluate the model
    evaluate = model.evaluate(test_ds, steps = test_ds.samples // test_ds.batch_size, verbose=1)

    # Append results to accuracy_test list
    history_key = list(history.history.keys()) # As names of metric names can be dynamic, we need to get the keys of the history object
    accuracy_test.append({
        'Base Model': pretrained_model.__name__,
        'duration': round(processing_time, 3),
        'test_accuracy': round(evaluate[1], 3),
        'test_precision': round(evaluate[2], 3),
        'test_recall': round(evaluate[3], 3),
        'test_loss': round(evaluate[0], 3),
        'train_accuracy': round(history.history[history_key[1]][-1],3),
        'train_precision': round(history.history[history_key[2]][-1],3),
        'train_recall': round(history.history[history_key[3]][-1],3),
        'train_auc' : round(history.history[history_key[4]][-1],3),
        'train_loss': round(history.history[history_key[0]][-1],3),
        'val_accuracy': round(history.history[history_key[6]][-1],3),
        'val_precision': round(history.history[history_key[7]][-1],3),
        'val_recall': round(history.history[history_key[8]][-1],3),
        'val_auc' : round(history.history[history_key[9]][-1],3),
        'val_loss': round(history.history[history_key[5]][-1],3)
    })
    
    epochs_report = pd.DataFrame(history.history)
    epochs_report.to_csv(f"{experiment_results_directory}/{pretrained_model.__name__}_epochs_report.csv", index=False)
    
    model.save(f"{experiment_models_directory}/{pretrained_model.__name__}_finetuned_model_{nameSuffix}.h5")

# Create DataFrame with accuracy score and export as .csv
accuracy_test_results = pd.DataFrame(accuracy_test)
accuracy_test_results.to_csv(f'{experiment_results_directory}/accuracy_test_results.csv', index=False)

# Generate graphs from epochs_reports.csv and output to results folder.
create_accuracy_plots(f"{experiment_results_directory}")
create_all_metrics_plots(f"{experiment_results_directory}")
# Out:
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  conv2d (Conv2D)             (None, 9, 9, 2048)        9439232
#
#  batch_normalization (BatchN  (None, 9, 9, 2048)       8192
#  ormalization)
#
#  activation (Activation)     (None, 9, 9, 2048)        0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 2048)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 2048)        37750784
#
#  batch_normalization_1 (Batc  (None, 4, 4, 2048)       8192
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 2048)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 2048)       0
#  2D)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 65,078,081
# Trainable params: 65,027,073
# Non-trainable params: 51,008
# _________________________________________________________________
# Epoch 1/50
# 2023-06-01 22:09:20.361801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
#  608/2414 [======>.......................] - ETA: 5:21 - loss: 0.7680 - binary_accuracy: 0.5731 - precision: 0.5644 - recall: 0.5495 - auc: 0.5963
# 2023-06-01 22:11:13.493700: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.37GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-01 22:11:13.568050: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-01 22:11:14.184716: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2414/2414 [==============================] - ETA: 0s - loss: 0.7348 - binary_accuracy: 0.5352 - precision: 0.5225 - recall: 0.4910 - auc: 0.5510
# 2023-06-01 22:16:37.695057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.68888, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.52762, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 475s 195ms/step - loss: 0.7348 - binary_accuracy: 0.5352 - precision: 0.5225 - recall: 0.4910 - auc: 0.5510 - val_loss: 0.6889 - val_binary_accuracy: 0.5276 - val_precision: 0.5598 - val_recall: 0.1308 - val_auc: 0.5828 - lr: 1.0000e-04
# Epoch 2/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.7053 - binary_accuracy: 0.5351 - precision: 0.5238 - recall: 0.4618 - auc: 0.5469
# Epoch 2: val_loss improved from 0.68888 to 0.67914, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 2: val_binary_accuracy improved from 0.52762 to 0.58052, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 467s 193ms/step - loss: 0.7053 - binary_accuracy: 0.5351 - precision: 0.5238 - recall: 0.4618 - auc: 0.5469 - val_loss: 0.6791 - val_binary_accuracy: 0.5805 - val_precision: 0.5885 - val_recall: 0.4553 - val_auc: 0.6067 - lr: 1.0000e-04
# Epoch 3/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6973 - binary_accuracy: 0.5384 - precision: 0.5285 - recall: 0.4548 - auc: 0.5523
# Epoch 3: val_loss did not improve from 0.67914
#
# Epoch 3: val_binary_accuracy did not improve from 0.58052
# 2414/2414 [==============================] - 468s 194ms/step - loss: 0.6973 - binary_accuracy: 0.5384 - precision: 0.5285 - recall: 0.4548 - auc: 0.5523 - val_loss: 0.7907 - val_binary_accuracy: 0.5458 - val_precision: 0.5220 - val_recall: 0.7827 - val_auc: 0.5482 - lr: 1.0000e-04
# Epoch 4/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6929 - binary_accuracy: 0.5426 - precision: 0.5336 - recall: 0.4565 - auc: 0.5551
# Epoch 4: val_loss improved from 0.67914 to 0.67497, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 4: val_binary_accuracy improved from 0.58052 to 0.58275, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 467s 193ms/step - loss: 0.6929 - binary_accuracy: 0.5426 - precision: 0.5336 - recall: 0.4565 - auc: 0.5551 - val_loss: 0.6750 - val_binary_accuracy: 0.5827 - val_precision: 0.6312 - val_recall: 0.3397 - val_auc: 0.6179 - lr: 1.0000e-04
# Epoch 5/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6817 - binary_accuracy: 0.5719 - precision: 0.5735 - recall: 0.4606 - auc: 0.5884
# Epoch 5: val_loss did not improve from 0.67497
#
# Epoch 5: val_binary_accuracy improved from 0.58275 to 0.59059, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 460s 190ms/step - loss: 0.6817 - binary_accuracy: 0.5719 - precision: 0.5735 - recall: 0.4606 - auc: 0.5884 - val_loss: 0.6863 - val_binary_accuracy: 0.5906 - val_precision: 0.5722 - val_recall: 0.6221 - val_auc: 0.6337 - lr: 1.0000e-04
# Epoch 6/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6780 - binary_accuracy: 0.5778 - precision: 0.5815 - recall: 0.4638 - auc: 0.5991
# Epoch 6: val_loss did not improve from 0.67497
#
# Epoch 6: val_binary_accuracy did not improve from 0.59059
# 2414/2414 [==============================] - 469s 194ms/step - loss: 0.6780 - binary_accuracy: 0.5778 - precision: 0.5815 - recall: 0.4638 - auc: 0.5991 - val_loss: 0.7164 - val_binary_accuracy: 0.5139 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6140 - lr: 1.0000e-04
# Epoch 7/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6708 - binary_accuracy: 0.5914 - precision: 0.5980 - recall: 0.4827 - auc: 0.6174
# Epoch 7: val_loss improved from 0.67497 to 0.66222, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 7: val_binary_accuracy improved from 0.59059 to 0.61166, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 469s 194ms/step - loss: 0.6708 - binary_accuracy: 0.5914 - precision: 0.5980 - recall: 0.4827 - auc: 0.6174 - val_loss: 0.6622 - val_binary_accuracy: 0.6117 - val_precision: 0.7127 - val_recall: 0.3378 - val_auc: 0.6618 - lr: 1.0000e-04
# Epoch 8/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6608 - binary_accuracy: 0.6101 - precision: 0.6222 - recall: 0.5009 - auc: 0.6404
# Epoch 8: val_loss improved from 0.66222 to 0.64908, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 8: val_binary_accuracy improved from 0.61166 to 0.62020, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 462s 191ms/step - loss: 0.6608 - binary_accuracy: 0.6101 - precision: 0.6222 - recall: 0.5009 - auc: 0.6404 - val_loss: 0.6491 - val_binary_accuracy: 0.6202 - val_precision: 0.6662 - val_recall: 0.4382 - val_auc: 0.6718 - lr: 1.0000e-04
# Epoch 9/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.6291 - binary_accuracy: 0.6510 - precision: 0.6600 - recall: 0.5794 - auc: 0.7001
# Epoch 9: val_loss improved from 0.64908 to 0.62603, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 9: val_binary_accuracy improved from 0.62020 to 0.64256, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 471s 195ms/step - loss: 0.6291 - binary_accuracy: 0.6510 - precision: 0.6600 - recall: 0.5794 - auc: 0.7001 - val_loss: 0.6260 - val_binary_accuracy: 0.6426 - val_precision: 0.7744 - val_recall: 0.3729 - val_auc: 0.7490 - lr: 1.0000e-04
# Epoch 10/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.5561 - binary_accuracy: 0.7166 - precision: 0.7182 - recall: 0.6848 - auc: 0.7887
# Epoch 10: val_loss improved from 0.62603 to 0.59389, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 10: val_binary_accuracy improved from 0.64256 to 0.69089, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 464s 192ms/step - loss: 0.5561 - binary_accuracy: 0.7166 - precision: 0.7182 - recall: 0.6848 - auc: 0.7887 - val_loss: 0.5939 - val_binary_accuracy: 0.6909 - val_precision: 0.8661 - val_recall: 0.4303 - val_auc: 0.8341 - lr: 1.0000e-04
# Epoch 11/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.4549 - binary_accuracy: 0.7897 - precision: 0.7809 - recall: 0.7876 - auc: 0.8682
# Epoch 11: val_loss improved from 0.59389 to 0.41378, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 11: val_binary_accuracy improved from 0.69089 to 0.81742, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 463s 192ms/step - loss: 0.4549 - binary_accuracy: 0.7897 - precision: 0.7809 - recall: 0.7876 - auc: 0.8682 - val_loss: 0.4138 - val_binary_accuracy: 0.8174 - val_precision: 0.8818 - val_recall: 0.7208 - val_auc: 0.9082 - lr: 1.0000e-04
# Epoch 12/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.3841 - binary_accuracy: 0.8309 - precision: 0.8213 - recall: 0.8327 - auc: 0.9083
# Epoch 12: val_loss did not improve from 0.41378
#
# Epoch 12: val_binary_accuracy did not improve from 0.81742
# 2414/2414 [==============================] - 467s 193ms/step - loss: 0.3841 - binary_accuracy: 0.8309 - precision: 0.8213 - recall: 0.8327 - auc: 0.9083 - val_loss: 0.7438 - val_binary_accuracy: 0.6646 - val_precision: 0.9270 - val_recall: 0.3364 - val_auc: 0.8610 - lr: 1.0000e-04
# Epoch 13/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.3448 - binary_accuracy: 0.8528 - precision: 0.8448 - recall: 0.8537 - auc: 0.9268
# Epoch 13: val_loss did not improve from 0.41378
#
# Epoch 13: val_binary_accuracy did not improve from 0.81742
# 2414/2414 [==============================] - 462s 191ms/step - loss: 0.3448 - binary_accuracy: 0.8528 - precision: 0.8448 - recall: 0.8537 - auc: 0.9268 - val_loss: 0.4547 - val_binary_accuracy: 0.7871 - val_precision: 0.9520 - val_recall: 0.5921 - val_auc: 0.9393 - lr: 1.0000e-04
# Epoch 14/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.3097 - binary_accuracy: 0.8704 - precision: 0.8636 - recall: 0.8706 - auc: 0.9411
# Epoch 14: val_loss improved from 0.41378 to 0.30968, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 14: val_binary_accuracy improved from 0.81742 to 0.87067, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 467s 194ms/step - loss: 0.3097 - binary_accuracy: 0.8704 - precision: 0.8636 - recall: 0.8706 - auc: 0.9411 - val_loss: 0.3097 - val_binary_accuracy: 0.8707 - val_precision: 0.8416 - val_recall: 0.9042 - val_auc: 0.9446 - lr: 1.0000e-04
# Epoch 15/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2867 - binary_accuracy: 0.8809 - precision: 0.8740 - recall: 0.8817 - auc: 0.9497
# Epoch 15: val_loss improved from 0.30968 to 0.25477, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 15: val_binary_accuracy improved from 0.87067 to 0.89174, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 460s 191ms/step - loss: 0.2867 - binary_accuracy: 0.8809 - precision: 0.8740 - recall: 0.8817 - auc: 0.9497 - val_loss: 0.2548 - val_binary_accuracy: 0.8917 - val_precision: 0.8763 - val_recall: 0.9048 - val_auc: 0.9620 - lr: 1.0000e-04
# Epoch 16/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2595 - binary_accuracy: 0.8952 - precision: 0.8880 - recall: 0.8971 - auc: 0.9587
# Epoch 16: val_loss did not improve from 0.25477
#
# Epoch 16: val_binary_accuracy did not improve from 0.89174
# 2414/2414 [==============================] - 467s 193ms/step - loss: 0.2595 - binary_accuracy: 0.8952 - precision: 0.8880 - recall: 0.8971 - auc: 0.9587 - val_loss: 0.3604 - val_binary_accuracy: 0.8409 - val_precision: 0.8200 - val_recall: 0.8624 - val_auc: 0.9220 - lr: 1.0000e-04
# Epoch 17/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2420 - binary_accuracy: 0.9039 - precision: 0.8984 - recall: 0.9043 - auc: 0.9639
# Epoch 17: val_loss did not improve from 0.25477
#
# Epoch 17: val_binary_accuracy did not improve from 0.89174
# 2414/2414 [==============================] - 463s 192ms/step - loss: 0.2420 - binary_accuracy: 0.9039 - precision: 0.8984 - recall: 0.9043 - auc: 0.9639 - val_loss: 0.3273 - val_binary_accuracy: 0.8572 - val_precision: 0.7825 - val_recall: 0.9781 - val_auc: 0.9681 - lr: 1.0000e-04
# Epoch 18/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2282 - binary_accuracy: 0.9100 - precision: 0.9063 - recall: 0.9085 - auc: 0.9679
# Epoch 18: val_loss improved from 0.25477 to 0.24463, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 18: val_binary_accuracy improved from 0.89174 to 0.89888, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 462s 191ms/step - loss: 0.2282 - binary_accuracy: 0.9100 - precision: 0.9063 - recall: 0.9085 - auc: 0.9679 - val_loss: 0.2446 - val_binary_accuracy: 0.8989 - val_precision: 0.8927 - val_recall: 0.9004 - val_auc: 0.9653 - lr: 1.0000e-04
# Epoch 19/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2109 - binary_accuracy: 0.9165 - precision: 0.9112 - recall: 0.9175 - auc: 0.9725
# Epoch 19: val_loss did not improve from 0.24463
#
# Epoch 19: val_binary_accuracy did not improve from 0.89888
# 2414/2414 [==============================] - 463s 192ms/step - loss: 0.2109 - binary_accuracy: 0.9165 - precision: 0.9112 - recall: 0.9175 - auc: 0.9725 - val_loss: 0.3338 - val_binary_accuracy: 0.8612 - val_precision: 0.9538 - val_recall: 0.7507 - val_auc: 0.9603 - lr: 1.0000e-04
# Epoch 20/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1988 - binary_accuracy: 0.9229 - precision: 0.9169 - recall: 0.9250 - auc: 0.9754
# Epoch 20: val_loss improved from 0.24463 to 0.22695, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 20: val_binary_accuracy improved from 0.89888 to 0.91222, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 464s 192ms/step - loss: 0.1988 - binary_accuracy: 0.9229 - precision: 0.9169 - recall: 0.9250 - auc: 0.9754 - val_loss: 0.2269 - val_binary_accuracy: 0.9122 - val_precision: 0.9215 - val_recall: 0.8957 - val_auc: 0.9702 - lr: 1.0000e-04
# Epoch 21/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1964 - binary_accuracy: 0.9235 - precision: 0.9192 - recall: 0.9235 - auc: 0.9759
# Epoch 21: val_loss did not improve from 0.22695
#
# Epoch 21: val_binary_accuracy did not improve from 0.91222
# 2414/2414 [==============================] - 464s 192ms/step - loss: 0.1964 - binary_accuracy: 0.9235 - precision: 0.9192 - recall: 0.9235 - auc: 0.9759 - val_loss: 0.3643 - val_binary_accuracy: 0.8544 - val_precision: 0.9761 - val_recall: 0.7179 - val_auc: 0.9677 - lr: 1.0000e-04
# Epoch 22/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1819 - binary_accuracy: 0.9305 - precision: 0.9266 - recall: 0.9306 - auc: 0.9793
# Epoch 22: val_loss did not improve from 0.22695
#
# Epoch 22: val_binary_accuracy did not improve from 0.91222
# 2414/2414 [==============================] - 465s 193ms/step - loss: 0.1819 - binary_accuracy: 0.9305 - precision: 0.9266 - recall: 0.9306 - auc: 0.9793 - val_loss: 0.3229 - val_binary_accuracy: 0.8730 - val_precision: 0.9485 - val_recall: 0.7811 - val_auc: 0.9662 - lr: 1.0000e-04
# Epoch 23/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1750 - binary_accuracy: 0.9339 - precision: 0.9289 - recall: 0.9354 - auc: 0.9805
# Epoch 23: val_loss did not improve from 0.22695
#
# Epoch 23: val_binary_accuracy did not improve from 0.91222
# 2414/2414 [==============================] - 463s 192ms/step - loss: 0.1750 - binary_accuracy: 0.9339 - precision: 0.9289 - recall: 0.9354 - auc: 0.9805 - val_loss: 0.2946 - val_binary_accuracy: 0.8837 - val_precision: 0.9499 - val_recall: 0.8031 - val_auc: 0.9678 - lr: 1.0000e-04
# Epoch 24/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1659 - binary_accuracy: 0.9378 - precision: 0.9345 - recall: 0.9375 - auc: 0.9824
# Epoch 24: val_loss did not improve from 0.22695
#
# Epoch 24: val_binary_accuracy did not improve from 0.91222
# 2414/2414 [==============================] - 469s 194ms/step - loss: 0.1659 - binary_accuracy: 0.9378 - precision: 0.9345 - recall: 0.9375 - auc: 0.9824 - val_loss: 0.2683 - val_binary_accuracy: 0.8941 - val_precision: 0.8719 - val_recall: 0.9166 - val_auc: 0.9605 - lr: 1.0000e-04
# Epoch 25/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1643 - binary_accuracy: 0.9390 - precision: 0.9352 - recall: 0.9394 - auc: 0.9827
# Epoch 25: val_loss improved from 0.22695 to 0.22381, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_vl.h5
#
# Epoch 25: val_binary_accuracy improved from 0.91222 to 0.91292, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 471s 195ms/step - loss: 0.1643 - binary_accuracy: 0.9390 - precision: 0.9352 - recall: 0.9394 - auc: 0.9827 - val_loss: 0.2238 - val_binary_accuracy: 0.9129 - val_precision: 0.9063 - val_recall: 0.9155 - val_auc: 0.9711 - lr: 1.0000e-04
# Epoch 26/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1550 - binary_accuracy: 0.9420 - precision: 0.9387 - recall: 0.9420 - auc: 0.9846
# Epoch 26: val_loss did not improve from 0.22381
#
# Epoch 26: val_binary_accuracy did not improve from 0.91292
# 2414/2414 [==============================] - 461s 191ms/step - loss: 0.1550 - binary_accuracy: 0.9420 - precision: 0.9387 - recall: 0.9420 - auc: 0.9846 - val_loss: 0.2782 - val_binary_accuracy: 0.9011 - val_precision: 0.8426 - val_recall: 0.9793 - val_auc: 0.9751 - lr: 1.0000e-04
# Epoch 27/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1423 - binary_accuracy: 0.9471 - precision: 0.9442 - recall: 0.9470 - auc: 0.9870
# Epoch 27: val_loss did not improve from 0.22381
#
# Epoch 27: val_binary_accuracy improved from 0.91292 to 0.91983, saving model to ../experiments/base-model-selection/BMS-0005/models/VGG16_model_augmented_ba.h5
# 2414/2414 [==============================] - 465s 193ms/step - loss: 0.1423 - binary_accuracy: 0.9471 - precision: 0.9442 - recall: 0.9470 - auc: 0.9870 - val_loss: 0.2321 - val_binary_accuracy: 0.9198 - val_precision: 0.9093 - val_recall: 0.9275 - val_auc: 0.9701 - lr: 1.0000e-04
# Epoch 28/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1488 - binary_accuracy: 0.9444 - precision: 0.9400 - recall: 0.9457 - auc: 0.9856
# Epoch 28: val_loss did not improve from 0.22381
#
# Epoch 28: val_binary_accuracy did not improve from 0.91983
# 2414/2414 [==============================] - 464s 192ms/step - loss: 0.1488 - binary_accuracy: 0.9444 - precision: 0.9400 - recall: 0.9457 - auc: 0.9856 - val_loss: 0.2977 - val_binary_accuracy: 0.8930 - val_precision: 0.8449 - val_recall: 0.9552 - val_auc: 0.9654 - lr: 1.0000e-04
# Epoch 29/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1341 - binary_accuracy: 0.9495 - precision: 0.9466 - recall: 0.9496 - auc: 0.9884
# Epoch 29: val_loss did not improve from 0.22381
#
# Epoch 29: val_binary_accuracy did not improve from 0.91983
# 2414/2414 [==============================] - 459s 190ms/step - loss: 0.1341 - binary_accuracy: 0.9495 - precision: 0.9466 - recall: 0.9496 - auc: 0.9884 - val_loss: 0.2723 - val_binary_accuracy: 0.8954 - val_precision: 0.8529 - val_recall: 0.9485 - val_auc: 0.9662 - lr: 1.0000e-04
# Epoch 30/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.2111 - binary_accuracy: 0.9232 - precision: 0.9178 - recall: 0.9245 - auc: 0.9728
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 30: val_loss did not improve from 0.22381
#
# Epoch 30: val_binary_accuracy did not improve from 0.91983
# 2414/2414 [==============================] - 464s 192ms/step - loss: 0.2111 - binary_accuracy: 0.9232 - precision: 0.9178 - recall: 0.9245 - auc: 0.9728 - val_loss: 0.2458 - val_binary_accuracy: 0.9081 - val_precision: 0.8622 - val_recall: 0.9653 - val_auc: 0.9741 - lr: 1.0000e-04
# Epoch 31/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.1136 - binary_accuracy: 0.9586 - precision: 0.9536 - recall: 0.9616 - auc: 0.9915
# Epoch 31: val_loss did not improve from 0.22381
#
# Epoch 31: val_binary_accuracy did not improve from 0.91983
# 2414/2414 [==============================] - 466s 193ms/step - loss: 0.1136 - binary_accuracy: 0.9586 - precision: 0.9536 - recall: 0.9616 - auc: 0.9915 - val_loss: 0.4369 - val_binary_accuracy: 0.8643 - val_precision: 0.7875 - val_recall: 0.9870 - val_auc: 0.9698 - lr: 5.0000e-05
# Epoch 32/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.0987 - binary_accuracy: 0.9663 - precision: 0.9634 - recall: 0.9672 - auc: 0.9931
# Epoch 32: val_loss did not improve from 0.22381
#
# Epoch 32: val_binary_accuracy did not improve from 0.91983
# 2414/2414 [==============================] - 463s 192ms/step - loss: 0.0987 - binary_accuracy: 0.9663 - precision: 0.9634 - recall: 0.9672 - auc: 0.9931 - val_loss: 0.2514 - val_binary_accuracy: 0.9039 - val_precision: 0.8871 - val_recall: 0.9194 - val_auc: 0.9668 - lr: 5.0000e-05
# Epoch 33/50
# 2414/2414 [==============================] - ETA: 0s - loss: 0.0976 - binary_accuracy: 0.9659 - precision: 0.9647 - recall: 0.9651 - auc: 0.9931
# Epoch 33: val_loss did not improve from 0.22381
#
# Epoch 33: val_binary_accuracy did not improve from 0.91983
# 2414/2414 [==============================] - 466s 193ms/step - loss: 0.0976 - binary_accuracy: 0.9659 - precision: 0.9647 - recall: 0.9651 - auc: 0.9931 - val_loss: 0.2830 - val_binary_accuracy: 0.9068 - val_precision: 0.8654 - val_recall: 0.9571 - val_auc: 0.9699 - lr: 5.0000e-05
# Epoch 33: early stopping
#   2/534 [..............................] - ETA: 36s - loss: 0.6344 - binary_accuracy: 0.8125 - precision: 0.7368 - recall: 0.9333 - auc: 0.9706
# 2023-06-02 02:25:10.774346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 534/534 [==============================] - 36s 68ms/step - loss: 0.2829 - binary_accuracy: 0.9068 - precision: 0.8655 - recall: 0.9572 - auc: 0.9699

# %% [markdown]
# ----
# ## Experiment #BMS-0006 | VGG19 Fine-Tuning
# **Experiment ID:** #BMS-0006
# **Experiment Description:**  Continuation of experiment BMS-0001, We load the pretrained models from the previous experiment and unfreeze the last 15 layers of the base model. The experiment we use VGG19 with data augmentation enabled.

# %%
# Experiment ID:BMS-0006
experimentId = "BMS-0006"

# Load Directories (Leave alone unless specifying a different dataset)
experiment_train_directory = train_directory
experiment_test_directory = test_directory
experiment_directory = f"{experiment_base_directory}/{experimentId}"
experiment_results_directory = f"{experiment_directory}/results"
experiment_models_directory = f"{experiment_directory}/models"
experiment_load_model_directory = "../experiments/base-model-selection/BMS-0001/models"

# Create directories if they don't exist
os.makedirs(name=experiment_directory, exist_ok=True)
os.makedirs(name=experiment_models_directory, exist_ok=True)
os.makedirs(name=experiment_results_directory, exist_ok=True)

# Declare lists for report generation
accuracy_report = []

# Declare Test Configurations
test_configurations = [
    [VGG19, vgg19_preprocess_input, 8, True],
]

# Declare accuracy_test list
accuracy_test = []

# Define Early Stopping Callback
early_stopping = EarlyStopping(
    monitor='val_loss', 
    mode='min', 
    verbose=1, 
    patience=8
)

# Define Reduce Learning Rate on Plateau Callback
lr_reducer = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    verbose=1,
)

# Loop through all combinations of models and trainable layers
for pretrained_model, preprocessing_function, batch_size, is_augmented in test_configurations:
    # Clear Session
    K.clear_session()
    
    # Setup Model Check Pointing
    
    nameSuffix = 'augmented' if is_augmented == True else 'not_augmented'
    model_checkpoint_vl = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_vl.h5",
        monitor='val_loss',
        mode='min',
        verbose=1,
        save_best_only=True
    )
    
    model_checkpoint_ba = ModelCheckpoint(
        filepath=f"{experiment_models_directory}/{pretrained_model.__name__}_model_{nameSuffix}_ba.h5",
        monitor='val_binary_accuracy',
        mode='max',
        verbose=1,
        save_best_only=True
    )
    
    # Create a dataset and preprocess images to suit base model
    train_ds, val_ds = create_train_val_datasets(preprocessing_function, experiment_train_directory, batch_size=batch_size, augment_data=is_augmented)
    test_ds = create_test_dataset(preprocessing_function, experiment_test_directory, batch_size=batch_size)

    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))


    #####################################################################################################################################
    # Load Previous Model and Weights
    #####################################################################################################################################

    # Load Model
    model = keras.models.load_model(
        f"{experiment_load_model_directory}/{pretrained_model.__name__}_model_{nameSuffix}.h5",
    )
    
    # Create Input Layer
    inputs = Input(shape=(299, 299, 3))

    # Base model is the second layer in the model
    base_model = model.layers[1]

    # Make Base Model Trainable
    base_model.trainable = True

    # Freeze the base model (do not train everything but last 15 layers)
    for layer in base_model.layers[:-15]:
        layer.trainable = False

    # Hookup Previous Model Layers to New Model
    inputs = keras.Input(shape=(299, 299, 3))
    x = base_model(inputs, training=False)
    
    # Traverse the layers and connect them
    for layer in model.layers[2:]:
        x = layer(x)
    
    # Define the model
    model = keras.Model(inputs=inputs, outputs=x)

    model.summary()
    # Compile the model
    model.compile(
        optimizer=Adam(1e-4),  
        loss=BinaryCrossentropy(from_logits=False),
        metrics=[BinaryAccuracy(), Precision(), Recall(), AUC()]
    )
    
    #####################################################################################################################################
    # Begin Fine Tuning Entire Model
    #####################################################################################################################################
    
    # Start Timer to measure processing time 
    start_time = time.time()

    # Train the model
    history = model.fit(
        train_ds, 
        steps_per_epoch=train_ds.samples // train_ds.batch_size,
        epochs=50, 
        validation_data=test_ds,
        validation_steps=test_ds.samples // test_ds.batch_size,
        callbacks = [early_stopping, lr_reducer, model_checkpoint_vl, model_checkpoint_ba]
    )
    
    # End Timer and calculate processing time
    end_time = time.time()
    processing_time = end_time - start_time

    # Evaluate the model
    evaluate = model.evaluate(test_ds, steps = test_ds.samples // test_ds.batch_size, verbose=1)

    # Append results to accuracy_test list
    history_key = list(history.history.keys()) # As names of metric names can be dynamic, we need to get the keys of the history object
    accuracy_test.append({
        'Base Model': pretrained_model.__name__,
        'duration': round(processing_time, 3),
        'test_accuracy': round(evaluate[1], 3),
        'test_precision': round(evaluate[2], 3),
        'test_recall': round(evaluate[3], 3),
        'test_loss': round(evaluate[0], 3),
        'train_accuracy': round(history.history[history_key[1]][-1],3),
        'train_precision': round(history.history[history_key[2]][-1],3),
        'train_recall': round(history.history[history_key[3]][-1],3),
        'train_auc' : round(history.history[history_key[4]][-1],3),
        'train_loss': round(history.history[history_key[0]][-1],3),
        'val_accuracy': round(history.history[history_key[6]][-1],3),
        'val_precision': round(history.history[history_key[7]][-1],3),
        'val_recall': round(history.history[history_key[8]][-1],3),
        'val_auc' : round(history.history[history_key[9]][-1],3),
        'val_loss': round(history.history[history_key[5]][-1],3)
    })
    
    epochs_report = pd.DataFrame(history.history)
    epochs_report.to_csv(f"{experiment_results_directory}/{pretrained_model.__name__}_epochs_report.csv", index=False)
    
    model.save(f"{experiment_models_directory}/{pretrained_model.__name__}_finetuned_model_{nameSuffix}.h5")

# Create DataFrame with accuracy score and export as .csv
accuracy_test_results = pd.DataFrame(accuracy_test)
accuracy_test_results.to_csv(f'{experiment_results_directory}/accuracy_test_results.csv', index=False)

# Generate graphs from epochs_reports.csv and output to results folder.
create_accuracy_plots(f"{experiment_results_directory}")
create_all_metrics_plots(f"{experiment_results_directory}")
# Out:
# Found 38634 images belonging to 2 classes.
# Found 9657 images belonging to 2 classes.
# Found 8557 images belonging to 2 classes.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  vgg19 (Functional)          (None, 9, 9, 512)         20024384
#
#  conv2d (Conv2D)             (None, 9, 9, 2048)        9439232
#
#  batch_normalization (BatchN  (None, 9, 9, 2048)       8192
#  ormalization)
#
#  activation (Activation)     (None, 9, 9, 2048)        0
#
#  max_pooling2d (MaxPooling2D  (None, 4, 4, 2048)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 2048)        37750784
#
#  batch_normalization_1 (Batc  (None, 4, 4, 2048)       8192
#  hNormalization)
#
#  activation_1 (Activation)   (None, 4, 4, 2048)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 2048)       0
#  2D)
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 70,387,777
# Trainable params: 70,115,329
# Non-trainable params: 272,448
# _________________________________________________________________
# Epoch 1/50
# 2023-06-02 18:31:09.681301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-02 18:31:14.564406: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 4829/4829 [==============================] - ETA: 0s - loss: 0.7184 - binary_accuracy: 0.5185 - precision: 0.5044 - recall: 0.4464 - auc: 0.5243
# 2023-06-02 18:40:30.614667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 0.74412, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 1: val_binary_accuracy improved from -inf to 0.48340, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 618s 127ms/step - loss: 0.7184 - binary_accuracy: 0.5185 - precision: 0.5044 - recall: 0.4464 - auc: 0.5243 - val_loss: 0.7441 - val_binary_accuracy: 0.4834 - val_precision: 0.4844 - val_recall: 0.9771 - val_auc: 0.5188 - lr: 1.0000e-04
# Epoch 2/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.7077 - binary_accuracy: 0.5036 - precision: 0.4865 - recall: 0.4109 - auc: 0.5000
# Epoch 2: val_loss improved from 0.74412 to 0.69329, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 2: val_binary_accuracy improved from 0.48340 to 0.52081, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 610s 126ms/step - loss: 0.7077 - binary_accuracy: 0.5036 - precision: 0.4865 - recall: 0.4109 - auc: 0.5000 - val_loss: 0.6933 - val_binary_accuracy: 0.5208 - val_precision: 0.5046 - val_recall: 0.7733 - val_auc: 0.5196 - lr: 1.0000e-04
# Epoch 3/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.6961 - binary_accuracy: 0.5175 - precision: 0.5034 - recall: 0.4322 - auc: 0.5253
# Epoch 3: val_loss did not improve from 0.69329
#
# Epoch 3: val_binary_accuracy did not improve from 0.52081
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.6961 - binary_accuracy: 0.5175 - precision: 0.5034 - recall: 0.4322 - auc: 0.5253 - val_loss: 0.7061 - val_binary_accuracy: 0.5085 - val_precision: 0.4971 - val_recall: 0.9336 - val_auc: 0.5938 - lr: 1.0000e-04
# Epoch 4/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.6818 - binary_accuracy: 0.5674 - precision: 0.5608 - recall: 0.5013 - auc: 0.5888
# Epoch 4: val_loss improved from 0.69329 to 0.68148, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 4: val_binary_accuracy improved from 0.52081 to 0.55402, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 610s 126ms/step - loss: 0.6818 - binary_accuracy: 0.5674 - precision: 0.5608 - recall: 0.5013 - auc: 0.5888 - val_loss: 0.6815 - val_binary_accuracy: 0.5540 - val_precision: 0.5265 - val_recall: 0.8134 - val_auc: 0.6370 - lr: 1.0000e-04
# Epoch 5/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.6766 - binary_accuracy: 0.5808 - precision: 0.5799 - recall: 0.4951 - auc: 0.6039
# Epoch 5: val_loss did not improve from 0.68148
#
# Epoch 5: val_binary_accuracy improved from 0.55402 to 0.56232, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.6766 - binary_accuracy: 0.5808 - precision: 0.5799 - recall: 0.4951 - auc: 0.6039 - val_loss: 0.6845 - val_binary_accuracy: 0.5623 - val_precision: 0.7555 - val_recall: 0.1479 - val_auc: 0.6506 - lr: 1.0000e-04
# Epoch 6/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.6266 - binary_accuracy: 0.6556 - precision: 0.6544 - recall: 0.6154 - auc: 0.7059
# Epoch 6: val_loss improved from 0.68148 to 0.61280, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 6: val_binary_accuracy improved from 0.56232 to 0.66324, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.6266 - binary_accuracy: 0.6556 - precision: 0.6544 - recall: 0.6154 - auc: 0.7059 - val_loss: 0.6128 - val_binary_accuracy: 0.6632 - val_precision: 0.8344 - val_recall: 0.3831 - val_auc: 0.7808 - lr: 1.0000e-04
# Epoch 7/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.5460 - binary_accuracy: 0.7325 - precision: 0.7279 - recall: 0.7166 - auc: 0.7991
# Epoch 7: val_loss improved from 0.61280 to 0.50162, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 7: val_binary_accuracy improved from 0.66324 to 0.75047, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.5460 - binary_accuracy: 0.7325 - precision: 0.7279 - recall: 0.7166 - auc: 0.7991 - val_loss: 0.5016 - val_binary_accuracy: 0.7505 - val_precision: 0.8607 - val_recall: 0.5802 - val_auc: 0.8682 - lr: 1.0000e-04
# Epoch 8/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.4834 - binary_accuracy: 0.7759 - precision: 0.7708 - recall: 0.7662 - auc: 0.8495
# Epoch 8: val_loss did not improve from 0.50162
#
# Epoch 8: val_binary_accuracy did not improve from 0.75047
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.4834 - binary_accuracy: 0.7759 - precision: 0.7708 - recall: 0.7662 - auc: 0.8495 - val_loss: 0.6282 - val_binary_accuracy: 0.6893 - val_precision: 0.6129 - val_recall: 0.9805 - val_auc: 0.9012 - lr: 1.0000e-04
# Epoch 9/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.4364 - binary_accuracy: 0.8049 - precision: 0.7969 - recall: 0.8026 - auc: 0.8799
# Epoch 9: val_loss improved from 0.50162 to 0.38792, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 9: val_binary_accuracy improved from 0.75047 to 0.81782, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 610s 126ms/step - loss: 0.4364 - binary_accuracy: 0.8049 - precision: 0.7969 - recall: 0.8026 - auc: 0.8799 - val_loss: 0.3879 - val_binary_accuracy: 0.8178 - val_precision: 0.7555 - val_recall: 0.9242 - val_auc: 0.9273 - lr: 1.0000e-04
# Epoch 10/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.4074 - binary_accuracy: 0.8228 - precision: 0.8124 - recall: 0.8256 - auc: 0.8962
# Epoch 10: val_loss did not improve from 0.38792
#
# Epoch 10: val_binary_accuracy did not improve from 0.81782
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.4074 - binary_accuracy: 0.8228 - precision: 0.8124 - recall: 0.8256 - auc: 0.8962 - val_loss: 0.4052 - val_binary_accuracy: 0.8041 - val_precision: 0.7272 - val_recall: 0.9552 - val_auc: 0.9321 - lr: 1.0000e-04
# Epoch 11/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.3686 - binary_accuracy: 0.8419 - precision: 0.8303 - recall: 0.8475 - auc: 0.9160
# Epoch 11: val_loss improved from 0.38792 to 0.31684, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 11: val_binary_accuracy improved from 0.81782 to 0.86436, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.3686 - binary_accuracy: 0.8419 - precision: 0.8303 - recall: 0.8475 - auc: 0.9160 - val_loss: 0.3168 - val_binary_accuracy: 0.8644 - val_precision: 0.9075 - val_recall: 0.8027 - val_auc: 0.9466 - lr: 1.0000e-04
# Epoch 12/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.3595 - binary_accuracy: 0.8482 - precision: 0.8391 - recall: 0.8504 - auc: 0.9202
# Epoch 12: val_loss did not improve from 0.31684
#
# Epoch 12: val_binary_accuracy did not improve from 0.86436
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.3595 - binary_accuracy: 0.8482 - precision: 0.8391 - recall: 0.8504 - auc: 0.9202 - val_loss: 0.4757 - val_binary_accuracy: 0.7878 - val_precision: 0.7003 - val_recall: 0.9848 - val_auc: 0.9514 - lr: 1.0000e-04
# Epoch 13/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.3327 - binary_accuracy: 0.8625 - precision: 0.8527 - recall: 0.8663 - auc: 0.9319
# Epoch 13: val_loss improved from 0.31684 to 0.29148, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 13: val_binary_accuracy improved from 0.86436 to 0.88716, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.3327 - binary_accuracy: 0.8625 - precision: 0.8527 - recall: 0.8663 - auc: 0.9319 - val_loss: 0.2915 - val_binary_accuracy: 0.8872 - val_precision: 0.9014 - val_recall: 0.8621 - val_auc: 0.9571 - lr: 1.0000e-04
# Epoch 14/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.3187 - binary_accuracy: 0.8684 - precision: 0.8577 - recall: 0.8737 - auc: 0.9374
# Epoch 14: val_loss did not improve from 0.29148
#
# Epoch 14: val_binary_accuracy did not improve from 0.88716
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.3187 - binary_accuracy: 0.8684 - precision: 0.8577 - recall: 0.8737 - auc: 0.9374 - val_loss: 0.3955 - val_binary_accuracy: 0.8231 - val_precision: 0.7373 - val_recall: 0.9880 - val_auc: 0.9654 - lr: 1.0000e-04
# Epoch 15/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.3052 - binary_accuracy: 0.8766 - precision: 0.8663 - recall: 0.8818 - auc: 0.9428
# Epoch 15: val_loss did not improve from 0.29148
#
# Epoch 15: val_binary_accuracy did not improve from 0.88716
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.3052 - binary_accuracy: 0.8766 - precision: 0.8663 - recall: 0.8818 - auc: 0.9428 - val_loss: 0.3073 - val_binary_accuracy: 0.8665 - val_precision: 0.8140 - val_recall: 0.9401 - val_auc: 0.9546 - lr: 1.0000e-04
# Epoch 16/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2831 - binary_accuracy: 0.8886 - precision: 0.8795 - recall: 0.8929 - auc: 0.9505
# Epoch 16: val_loss improved from 0.29148 to 0.26219, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 16: val_binary_accuracy improved from 0.88716 to 0.89020, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 610s 126ms/step - loss: 0.2831 - binary_accuracy: 0.8886 - precision: 0.8795 - recall: 0.8929 - auc: 0.9505 - val_loss: 0.2622 - val_binary_accuracy: 0.8902 - val_precision: 0.8647 - val_recall: 0.9177 - val_auc: 0.9614 - lr: 1.0000e-04
# Epoch 17/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2724 - binary_accuracy: 0.8944 - precision: 0.8878 - recall: 0.8957 - auc: 0.9542
# Epoch 17: val_loss did not improve from 0.26219
#
# Epoch 17: val_binary_accuracy did not improve from 0.89020
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2724 - binary_accuracy: 0.8944 - precision: 0.8878 - recall: 0.8957 - auc: 0.9542 - val_loss: 0.2995 - val_binary_accuracy: 0.8709 - val_precision: 0.8352 - val_recall: 0.9148 - val_auc: 0.9495 - lr: 1.0000e-04
# Epoch 18/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2659 - binary_accuracy: 0.8976 - precision: 0.8920 - recall: 0.8976 - auc: 0.9566
# Epoch 18: val_loss did not improve from 0.26219
#
# Epoch 18: val_binary_accuracy did not improve from 0.89020
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2659 - binary_accuracy: 0.8976 - precision: 0.8920 - recall: 0.8976 - auc: 0.9566 - val_loss: 0.3044 - val_binary_accuracy: 0.8803 - val_precision: 0.8181 - val_recall: 0.9692 - val_auc: 0.9651 - lr: 1.0000e-04
# Epoch 19/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2691 - binary_accuracy: 0.8980 - precision: 0.8911 - recall: 0.8998 - auc: 0.9554
# Epoch 19: val_loss did not improve from 0.26219
#
# Epoch 19: val_binary_accuracy did not improve from 0.89020
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.2691 - binary_accuracy: 0.8980 - precision: 0.8911 - recall: 0.8998 - auc: 0.9554 - val_loss: 0.4711 - val_binary_accuracy: 0.7784 - val_precision: 0.9704 - val_recall: 0.5610 - val_auc: 0.9418 - lr: 1.0000e-04
# Epoch 20/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2490 - binary_accuracy: 0.9080 - precision: 0.9022 - recall: 0.9091 - auc: 0.9614
# Epoch 20: val_loss improved from 0.26219 to 0.24538, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 20: val_binary_accuracy improved from 0.89020 to 0.90037, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 610s 126ms/step - loss: 0.2490 - binary_accuracy: 0.9080 - precision: 0.9022 - recall: 0.9091 - auc: 0.9614 - val_loss: 0.2454 - val_binary_accuracy: 0.9004 - val_precision: 0.8686 - val_recall: 0.9367 - val_auc: 0.9671 - lr: 1.0000e-04
# Epoch 21/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2383 - binary_accuracy: 0.9130 - precision: 0.9065 - recall: 0.9151 - auc: 0.9647
# Epoch 21: val_loss did not improve from 0.24538
#
# Epoch 21: val_binary_accuracy did not improve from 0.90037
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2383 - binary_accuracy: 0.9130 - precision: 0.9065 - recall: 0.9151 - auc: 0.9647 - val_loss: 0.3551 - val_binary_accuracy: 0.8590 - val_precision: 0.7864 - val_recall: 0.9745 - val_auc: 0.9668 - lr: 1.0000e-04
# Epoch 22/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2303 - binary_accuracy: 0.9158 - precision: 0.9080 - recall: 0.9197 - auc: 0.9669
# Epoch 22: val_loss did not improve from 0.24538
#
# Epoch 22: val_binary_accuracy did not improve from 0.90037
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.2303 - binary_accuracy: 0.9158 - precision: 0.9080 - recall: 0.9197 - auc: 0.9669 - val_loss: 0.3167 - val_binary_accuracy: 0.8681 - val_precision: 0.8009 - val_recall: 0.9697 - val_auc: 0.9620 - lr: 1.0000e-04
# Epoch 23/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2333 - binary_accuracy: 0.9141 - precision: 0.9053 - recall: 0.9192 - auc: 0.9661
# Epoch 23: val_loss did not improve from 0.24538
#
# Epoch 23: val_binary_accuracy did not improve from 0.90037
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2333 - binary_accuracy: 0.9141 - precision: 0.9053 - recall: 0.9192 - auc: 0.9661 - val_loss: 0.2689 - val_binary_accuracy: 0.8904 - val_precision: 0.8392 - val_recall: 0.9581 - val_auc: 0.9698 - lr: 1.0000e-04
# Epoch 24/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.3611 - binary_accuracy: 0.8481 - precision: 0.8336 - recall: 0.8584 - auc: 0.9228
# Epoch 24: val_loss improved from 0.24538 to 0.24164, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 24: val_binary_accuracy did not improve from 0.90037
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.3611 - binary_accuracy: 0.8481 - precision: 0.8336 - recall: 0.8584 - auc: 0.9228 - val_loss: 0.2416 - val_binary_accuracy: 0.8956 - val_precision: 0.9392 - val_recall: 0.8395 - val_auc: 0.9694 - lr: 1.0000e-04
# Epoch 25/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2192 - binary_accuracy: 0.9215 - precision: 0.9148 - recall: 0.9244 - auc: 0.9701
# Epoch 25: val_loss improved from 0.24164 to 0.23491, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 25: val_binary_accuracy improved from 0.90037 to 0.90236, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2192 - binary_accuracy: 0.9215 - precision: 0.9148 - recall: 0.9244 - auc: 0.9701 - val_loss: 0.2349 - val_binary_accuracy: 0.9024 - val_precision: 0.9196 - val_recall: 0.8756 - val_auc: 0.9676 - lr: 1.0000e-04
# Epoch 26/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.3045 - binary_accuracy: 0.8843 - precision: 0.8746 - recall: 0.8891 - auc: 0.9445
# Epoch 26: val_loss did not improve from 0.23491
#
# Epoch 26: val_binary_accuracy did not improve from 0.90236
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.3045 - binary_accuracy: 0.8843 - precision: 0.8746 - recall: 0.8891 - auc: 0.9445 - val_loss: 0.3305 - val_binary_accuracy: 0.8533 - val_precision: 0.7854 - val_recall: 0.9605 - val_auc: 0.9598 - lr: 1.0000e-04
# Epoch 27/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2211 - binary_accuracy: 0.9219 - precision: 0.9152 - recall: 0.9249 - auc: 0.9695
# Epoch 27: val_loss did not improve from 0.23491
#
# Epoch 27: val_binary_accuracy did not improve from 0.90236
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.2211 - binary_accuracy: 0.9219 - precision: 0.9152 - recall: 0.9249 - auc: 0.9695 - val_loss: 0.2876 - val_binary_accuracy: 0.8746 - val_precision: 0.8475 - val_recall: 0.9050 - val_auc: 0.9513 - lr: 1.0000e-04
# Epoch 28/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2058 - binary_accuracy: 0.9276 - precision: 0.9228 - recall: 0.9285 - auc: 0.9733
# Epoch 28: val_loss did not improve from 0.23491
#
# Epoch 28: val_binary_accuracy did not improve from 0.90236
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2058 - binary_accuracy: 0.9276 - precision: 0.9228 - recall: 0.9285 - auc: 0.9733 - val_loss: 0.3176 - val_binary_accuracy: 0.8815 - val_precision: 0.8272 - val_recall: 0.9560 - val_auc: 0.9615 - lr: 1.0000e-04
# Epoch 29/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1990 - binary_accuracy: 0.9282 - precision: 0.9235 - recall: 0.9290 - auc: 0.9753
# Epoch 29: val_loss did not improve from 0.23491
#
# Epoch 29: val_binary_accuracy did not improve from 0.90236
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.1990 - binary_accuracy: 0.9282 - precision: 0.9235 - recall: 0.9290 - auc: 0.9753 - val_loss: 0.2847 - val_binary_accuracy: 0.8744 - val_precision: 0.8970 - val_recall: 0.8379 - val_auc: 0.9535 - lr: 1.0000e-04
# Epoch 30/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2089 - binary_accuracy: 0.9274 - precision: 0.9212 - recall: 0.9300 - auc: 0.9723
# Epoch 30: val_loss improved from 0.23491 to 0.21615, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 30: val_binary_accuracy improved from 0.90236 to 0.91534, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 610s 126ms/step - loss: 0.2089 - binary_accuracy: 0.9274 - precision: 0.9212 - recall: 0.9300 - auc: 0.9723 - val_loss: 0.2161 - val_binary_accuracy: 0.9153 - val_precision: 0.8904 - val_recall: 0.9418 - val_auc: 0.9745 - lr: 1.0000e-04
# Epoch 31/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2414 - binary_accuracy: 0.9103 - precision: 0.9010 - recall: 0.9158 - auc: 0.9650
# Epoch 31: val_loss improved from 0.21615 to 0.20614, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 31: val_binary_accuracy improved from 0.91534 to 0.91674, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.2414 - binary_accuracy: 0.9103 - precision: 0.9010 - recall: 0.9158 - auc: 0.9650 - val_loss: 0.2061 - val_binary_accuracy: 0.9167 - val_precision: 0.8870 - val_recall: 0.9497 - val_auc: 0.9776 - lr: 1.0000e-04
# Epoch 32/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2139 - binary_accuracy: 0.9216 - precision: 0.9131 - recall: 0.9267 - auc: 0.9716
# Epoch 32: val_loss did not improve from 0.20614
#
# Epoch 32: val_binary_accuracy did not improve from 0.91674
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2139 - binary_accuracy: 0.9216 - precision: 0.9131 - recall: 0.9267 - auc: 0.9716 - val_loss: 0.2561 - val_binary_accuracy: 0.8997 - val_precision: 0.8494 - val_recall: 0.9646 - val_auc: 0.9731 - lr: 1.0000e-04
# Epoch 33/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2166 - binary_accuracy: 0.9243 - precision: 0.9194 - recall: 0.9251 - auc: 0.9714
# Epoch 33: val_loss did not improve from 0.20614
#
# Epoch 33: val_binary_accuracy did not improve from 0.91674
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.2166 - binary_accuracy: 0.9243 - precision: 0.9194 - recall: 0.9251 - auc: 0.9714 - val_loss: 0.3733 - val_binary_accuracy: 0.8412 - val_precision: 0.7797 - val_recall: 0.9384 - val_auc: 0.9325 - lr: 1.0000e-04
# Epoch 34/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1872 - binary_accuracy: 0.9344 - precision: 0.9280 - recall: 0.9376 - auc: 0.9777
# Epoch 34: val_loss did not improve from 0.20614
#
# Epoch 34: val_binary_accuracy did not improve from 0.91674
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.1872 - binary_accuracy: 0.9344 - precision: 0.9280 - recall: 0.9376 - auc: 0.9777 - val_loss: 0.2239 - val_binary_accuracy: 0.9093 - val_precision: 0.9134 - val_recall: 0.8985 - val_auc: 0.9704 - lr: 1.0000e-04
# Epoch 35/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.2527 - binary_accuracy: 0.9055 - precision: 0.9007 - recall: 0.9050 - auc: 0.9618
# Epoch 35: val_loss did not improve from 0.20614
#
# Epoch 35: val_binary_accuracy did not improve from 0.91674
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.2527 - binary_accuracy: 0.9055 - precision: 0.9007 - recall: 0.9050 - auc: 0.9618 - val_loss: 0.2826 - val_binary_accuracy: 0.8822 - val_precision: 0.8225 - val_recall: 0.9663 - val_auc: 0.9706 - lr: 1.0000e-04
# Epoch 36/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1784 - binary_accuracy: 0.9381 - precision: 0.9316 - recall: 0.9415 - auc: 0.9797
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 36: val_loss did not improve from 0.20614
#
# Epoch 36: val_binary_accuracy did not improve from 0.91674
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.1784 - binary_accuracy: 0.9381 - precision: 0.9316 - recall: 0.9415 - auc: 0.9797 - val_loss: 0.2567 - val_binary_accuracy: 0.8928 - val_precision: 0.9103 - val_recall: 0.8646 - val_auc: 0.9609 - lr: 1.0000e-04
# Epoch 37/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1394 - binary_accuracy: 0.9557 - precision: 0.9527 - recall: 0.9562 - auc: 0.9866
# Epoch 37: val_loss did not improve from 0.20614
#
# Epoch 37: val_binary_accuracy did not improve from 0.91674
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.1394 - binary_accuracy: 0.9557 - precision: 0.9527 - recall: 0.9562 - auc: 0.9866 - val_loss: 0.2255 - val_binary_accuracy: 0.9122 - val_precision: 0.8874 - val_recall: 0.9384 - val_auc: 0.9733 - lr: 5.0000e-05
# Epoch 38/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1675 - binary_accuracy: 0.9436 - precision: 0.9331 - recall: 0.9520 - auc: 0.9820
# Epoch 38: val_loss improved from 0.20614 to 0.20390, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 38: val_binary_accuracy improved from 0.91674 to 0.91733, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.1675 - binary_accuracy: 0.9436 - precision: 0.9331 - recall: 0.9520 - auc: 0.9820 - val_loss: 0.2039 - val_binary_accuracy: 0.9173 - val_precision: 0.9025 - val_recall: 0.9305 - val_auc: 0.9754 - lr: 5.0000e-05
# Epoch 39/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1256 - binary_accuracy: 0.9605 - precision: 0.9560 - recall: 0.9630 - auc: 0.9888
# Epoch 39: val_loss did not improve from 0.20390
#
# Epoch 39: val_binary_accuracy did not improve from 0.91733
# 4829/4829 [==============================] - 605s 125ms/step - loss: 0.1256 - binary_accuracy: 0.9605 - precision: 0.9560 - recall: 0.9630 - auc: 0.9888 - val_loss: 0.2771 - val_binary_accuracy: 0.8964 - val_precision: 0.8447 - val_recall: 0.9642 - val_auc: 0.9732 - lr: 5.0000e-05
# Epoch 40/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1229 - binary_accuracy: 0.9613 - precision: 0.9571 - recall: 0.9635 - auc: 0.9894
# Epoch 40: val_loss improved from 0.20390 to 0.18689, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_vl.h5
#
# Epoch 40: val_binary_accuracy improved from 0.91733 to 0.92832, saving model to ../experiments/base-model-selection/BMS-0006/models/VGG19_model_augmented_ba.h5
# 4829/4829 [==============================] - 612s 127ms/step - loss: 0.1229 - binary_accuracy: 0.9613 - precision: 0.9571 - recall: 0.9635 - auc: 0.9894 - val_loss: 0.1869 - val_binary_accuracy: 0.9283 - val_precision: 0.9243 - val_recall: 0.9285 - val_auc: 0.9792 - lr: 5.0000e-05
# Epoch 41/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1167 - binary_accuracy: 0.9633 - precision: 0.9601 - recall: 0.9645 - auc: 0.9904
# Epoch 41: val_loss did not improve from 0.18689
#
# Epoch 41: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.1167 - binary_accuracy: 0.9633 - precision: 0.9601 - recall: 0.9645 - auc: 0.9904 - val_loss: 2.3915 - val_binary_accuracy: 0.6971 - val_precision: 0.6399 - val_recall: 0.8627 - val_auc: 0.8001 - lr: 5.0000e-05
# Epoch 42/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1226 - binary_accuracy: 0.9617 - precision: 0.9586 - recall: 0.9627 - auc: 0.9893
# Epoch 42: val_loss did not improve from 0.18689
#
# Epoch 42: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 607s 126ms/step - loss: 0.1226 - binary_accuracy: 0.9617 - precision: 0.9586 - recall: 0.9627 - auc: 0.9893 - val_loss: 0.2448 - val_binary_accuracy: 0.9116 - val_precision: 0.8705 - val_recall: 0.9610 - val_auc: 0.9746 - lr: 5.0000e-05
# Epoch 43/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1136 - binary_accuracy: 0.9646 - precision: 0.9616 - recall: 0.9655 - auc: 0.9907
# Epoch 43: val_loss did not improve from 0.18689
#
# Epoch 43: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 610s 126ms/step - loss: 0.1136 - binary_accuracy: 0.9646 - precision: 0.9616 - recall: 0.9655 - auc: 0.9907 - val_loss: 0.3668 - val_binary_accuracy: 0.8658 - val_precision: 0.8126 - val_recall: 0.9408 - val_auc: 0.9539 - lr: 5.0000e-05
# Epoch 44/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1563 - binary_accuracy: 0.9468 - precision: 0.9461 - recall: 0.9443 - auc: 0.9846
# Epoch 44: val_loss did not improve from 0.18689
#
# Epoch 44: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.1563 - binary_accuracy: 0.9468 - precision: 0.9461 - recall: 0.9443 - auc: 0.9846 - val_loss: 0.5175 - val_binary_accuracy: 0.8133 - val_precision: 0.7263 - val_recall: 0.9882 - val_auc: 0.9592 - lr: 5.0000e-05
# Epoch 45/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.1090 - binary_accuracy: 0.9658 - precision: 0.9625 - recall: 0.9672 - auc: 0.9918
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 45: val_loss did not improve from 0.18689
#
# Epoch 45: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.1090 - binary_accuracy: 0.9658 - precision: 0.9625 - recall: 0.9672 - auc: 0.9918 - val_loss: 0.2964 - val_binary_accuracy: 0.9001 - val_precision: 0.8529 - val_recall: 0.9600 - val_auc: 0.9706 - lr: 5.0000e-05
# Epoch 46/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.0888 - binary_accuracy: 0.9736 - precision: 0.9717 - recall: 0.9740 - auc: 0.9938
# Epoch 46: val_loss did not improve from 0.18689
#
# Epoch 46: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.0888 - binary_accuracy: 0.9736 - precision: 0.9717 - recall: 0.9740 - auc: 0.9938 - val_loss: 0.3051 - val_binary_accuracy: 0.9043 - val_precision: 0.8833 - val_recall: 0.9254 - val_auc: 0.9655 - lr: 2.5000e-05
# Epoch 47/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.0802 - binary_accuracy: 0.9760 - precision: 0.9746 - recall: 0.9759 - auc: 0.9945
# Epoch 47: val_loss did not improve from 0.18689
#
# Epoch 47: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 608s 126ms/step - loss: 0.0802 - binary_accuracy: 0.9760 - precision: 0.9746 - recall: 0.9759 - auc: 0.9945 - val_loss: 0.2769 - val_binary_accuracy: 0.9081 - val_precision: 0.8679 - val_recall: 0.9565 - val_auc: 0.9727 - lr: 2.5000e-05
# Epoch 48/50
# 4829/4829 [==============================] - ETA: 0s - loss: 0.0751 - binary_accuracy: 0.9780 - precision: 0.9753 - recall: 0.9796 - auc: 0.9951
# Epoch 48: val_loss did not improve from 0.18689
#
# Epoch 48: val_binary_accuracy did not improve from 0.92832
# 4829/4829 [==============================] - 609s 126ms/step - loss: 0.0751 - binary_accuracy: 0.9780 - precision: 0.9753 - recall: 0.9796 - auc: 0.9951 - val_loss: 0.2651 - val_binary_accuracy: 0.9069 - val_precision: 0.8668 - val_recall: 0.9553 - val_auc: 0.9737 - lr: 2.5000e-05
# Epoch 48: early stopping
#    3/1069 [..............................] - ETA: 55s - loss: 0.0523 - binary_accuracy: 0.9583 - precision: 0.9333 - recall: 1.0000 - auc: 1.0000
# 2023-06-03 02:38:04.325750: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 1069/1069 [==============================] - 56s 53ms/step - loss: 0.2651 - binary_accuracy: 0.9069 - precision: 0.8669 - recall: 0.9553 - auc: 0.9737
